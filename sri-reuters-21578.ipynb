# %% [markdown]
# # PROYECTO BIMESTRAL: Sistema de Recuperación de Información basado en Reuters-21578¶
# ## Integrantes: Madelyn Fernandez, Carlos Sanchez, Kevin Valle
# ### Fases del Proyecto

# %% [markdown]
# # 1. Adquisición de Datos

# %% [markdown]
# Importación de modulos y liberias a utilizar

# %%
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import nltk
import re
import string
from nltk.corpus import LazyCorpusLoader, CategorizedPlaintextCorpusReader
from nltk.stem import PorterStemmer, SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from collections import defaultdict
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# A continuación, se presenta y obtiene los datos necesarios para la realización del Proyecto.

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/reuters/reuters/cats.txt
# /kaggle/input/reuters/reuters/README
# /kaggle/input/reuters/reuters/stopwords
# /kaggle/input/reuters/reuters/training/3347
# /kaggle/input/reuters/reuters/training/3531
# /kaggle/input/reuters/reuters/training/11840
# /kaggle/input/reuters/reuters/training/1520
# /kaggle/input/reuters/reuters/training/7521
# /kaggle/input/reuters/reuters/training/4951
# /kaggle/input/reuters/reuters/training/1446
# /kaggle/input/reuters/reuters/training/1215
# /kaggle/input/reuters/reuters/training/5684
# /kaggle/input/reuters/reuters/training/248
# /kaggle/input/reuters/reuters/training/9377
# /kaggle/input/reuters/reuters/training/9547
# /kaggle/input/reuters/reuters/training/14440
# /kaggle/input/reuters/reuters/training/8941
# /kaggle/input/reuters/reuters/training/3189
# /kaggle/input/reuters/reuters/training/6946
# /kaggle/input/reuters/reuters/training/9615
# /kaggle/input/reuters/reuters/training/1260
# /kaggle/input/reuters/reuters/training/8656
# /kaggle/input/reuters/reuters/training/6432
# /kaggle/input/reuters/reuters/training/1739
# /kaggle/input/reuters/reuters/training/1845
# /kaggle/input/reuters/reuters/training/1151
# /kaggle/input/reuters/reuters/training/12391
# /kaggle/input/reuters/reuters/training/6130
# /kaggle/input/reuters/reuters/training/3775
# /kaggle/input/reuters/reuters/training/1582
# /kaggle/input/reuters/reuters/training/10587
# /kaggle/input/reuters/reuters/training/3757
# /kaggle/input/reuters/reuters/training/4062
# /kaggle/input/reuters/reuters/training/3065
# /kaggle/input/reuters/reuters/training/12969
# /kaggle/input/reuters/reuters/training/10295
# /kaggle/input/reuters/reuters/training/3517
# /kaggle/input/reuters/reuters/training/843
# /kaggle/input/reuters/reuters/training/11276
# /kaggle/input/reuters/reuters/training/135
# /kaggle/input/reuters/reuters/training/2743
# /kaggle/input/reuters/reuters/training/1316
# /kaggle/input/reuters/reuters/training/8060
# /kaggle/input/reuters/reuters/training/5994
# /kaggle/input/reuters/reuters/training/9583
# /kaggle/input/reuters/reuters/training/10240
# /kaggle/input/reuters/reuters/training/3821
# /kaggle/input/reuters/reuters/training/9021
# /kaggle/input/reuters/reuters/training/5667
# /kaggle/input/reuters/reuters/training/12411
# /kaggle/input/reuters/reuters/training/10585
# /kaggle/input/reuters/reuters/training/13757
# /kaggle/input/reuters/reuters/training/6912
# /kaggle/input/reuters/reuters/training/7003
# /kaggle/input/reuters/reuters/training/13744
# /kaggle/input/reuters/reuters/training/11098
# /kaggle/input/reuters/reuters/training/12371
# /kaggle/input/reuters/reuters/training/2191
# /kaggle/input/reuters/reuters/training/1156
# /kaggle/input/reuters/reuters/training/47
# /kaggle/input/reuters/reuters/training/4261
# /kaggle/input/reuters/reuters/training/7554
# /kaggle/input/reuters/reuters/training/4743
# /kaggle/input/reuters/reuters/training/6677
# /kaggle/input/reuters/reuters/training/2699
# /kaggle/input/reuters/reuters/training/3076
# /kaggle/input/reuters/reuters/training/3125
# /kaggle/input/reuters/reuters/training/2626
# /kaggle/input/reuters/reuters/training/183
# /kaggle/input/reuters/reuters/training/5127
# /kaggle/input/reuters/reuters/training/2337
# /kaggle/input/reuters/reuters/training/2460
# /kaggle/input/reuters/reuters/training/13026
# /kaggle/input/reuters/reuters/training/13064
# /kaggle/input/reuters/reuters/training/6375
# /kaggle/input/reuters/reuters/training/6562
# /kaggle/input/reuters/reuters/training/3851
# /kaggle/input/reuters/reuters/training/768
# /kaggle/input/reuters/reuters/training/13238
# /kaggle/input/reuters/reuters/training/4937
# /kaggle/input/reuters/reuters/training/3210
# /kaggle/input/reuters/reuters/training/5535
# /kaggle/input/reuters/reuters/training/11460
# /kaggle/input/reuters/reuters/training/4507
# /kaggle/input/reuters/reuters/training/3118
# /kaggle/input/reuters/reuters/training/1851
# /kaggle/input/reuters/reuters/training/2109
# /kaggle/input/reuters/reuters/training/5359
# /kaggle/input/reuters/reuters/training/3138
# /kaggle/input/reuters/reuters/training/1535
# /kaggle/input/reuters/reuters/training/6909
# /kaggle/input/reuters/reuters/training/1975
# /kaggle/input/reuters/reuters/training/4127
# /kaggle/input/reuters/reuters/training/3305
# /kaggle/input/reuters/reuters/training/3458
# /kaggle/input/reuters/reuters/training/9614
# /kaggle/input/reuters/reuters/training/7583
# /kaggle/input/reuters/reuters/training/12420
# /kaggle/input/reuters/reuters/training/1803
# /kaggle/input/reuters/reuters/training/10751
# /kaggle/input/reuters/reuters/training/2326
# /kaggle/input/reuters/reuters/training/10788
# /kaggle/input/reuters/reuters/training/3800
# /kaggle/input/reuters/reuters/training/9505
# /kaggle/input/reuters/reuters/training/6922
# /kaggle/input/reuters/reuters/training/1633
# /kaggle/input/reuters/reuters/training/10860
# /kaggle/input/reuters/reuters/training/313
# /kaggle/input/reuters/reuters/training/5171
# /kaggle/input/reuters/reuters/training/3942
# /kaggle/input/reuters/reuters/training/6342
# /kaggle/input/reuters/reuters/training/1543
# /kaggle/input/reuters/reuters/training/4577
# /kaggle/input/reuters/reuters/training/5671
# /kaggle/input/reuters/reuters/training/6774
# /kaggle/input/reuters/reuters/training/6339
# /kaggle/input/reuters/reuters/training/11504
# /kaggle/input/reuters/reuters/training/6209
# /kaggle/input/reuters/reuters/training/5500
# /kaggle/input/reuters/reuters/training/12572
# /kaggle/input/reuters/reuters/training/2791
# /kaggle/input/reuters/reuters/training/7097
# /kaggle/input/reuters/reuters/training/5465
# /kaggle/input/reuters/reuters/training/4609
# /kaggle/input/reuters/reuters/training/8884
# /kaggle/input/reuters/reuters/training/5650
# /kaggle/input/reuters/reuters/training/10446
# /kaggle/input/reuters/reuters/training/2990
# /kaggle/input/reuters/reuters/training/12040
# /kaggle/input/reuters/reuters/training/4385
# /kaggle/input/reuters/reuters/training/5926
# /kaggle/input/reuters/reuters/training/1678
# /kaggle/input/reuters/reuters/training/6197
# /kaggle/input/reuters/reuters/training/11343
# /kaggle/input/reuters/reuters/training/6225
# /kaggle/input/reuters/reuters/training/9531
# /kaggle/input/reuters/reuters/training/5162
# /kaggle/input/reuters/reuters/training/7520
# /kaggle/input/reuters/reuters/training/1909
# /kaggle/input/reuters/reuters/training/7566
# /kaggle/input/reuters/reuters/training/14201
# /kaggle/input/reuters/reuters/training/7504
# /kaggle/input/reuters/reuters/training/4066
# /kaggle/input/reuters/reuters/training/2434
# /kaggle/input/reuters/reuters/training/3768
# /kaggle/input/reuters/reuters/training/12529
# /kaggle/input/reuters/reuters/training/3131
# /kaggle/input/reuters/reuters/training/6811
# /kaggle/input/reuters/reuters/training/10361
# /kaggle/input/reuters/reuters/training/1488
# /kaggle/input/reuters/reuters/training/13070
# /kaggle/input/reuters/reuters/training/6274
# /kaggle/input/reuters/reuters/training/11629
# /kaggle/input/reuters/reuters/training/5967
# /kaggle/input/reuters/reuters/training/2960
# /kaggle/input/reuters/reuters/training/11549
# /kaggle/input/reuters/reuters/training/4835
# /kaggle/input/reuters/reuters/training/8294
# /kaggle/input/reuters/reuters/training/3903
# /kaggle/input/reuters/reuters/training/7993
# /kaggle/input/reuters/reuters/training/10173
# /kaggle/input/reuters/reuters/training/7877
# /kaggle/input/reuters/reuters/training/1966
# /kaggle/input/reuters/reuters/training/9337
# /kaggle/input/reuters/reuters/training/81
# /kaggle/input/reuters/reuters/training/13027
# /kaggle/input/reuters/reuters/training/7006
# /kaggle/input/reuters/reuters/training/7723
# /kaggle/input/reuters/reuters/training/4678
# /kaggle/input/reuters/reuters/training/1590
# /kaggle/input/reuters/reuters/training/5499
# /kaggle/input/reuters/reuters/training/2652
# /kaggle/input/reuters/reuters/training/12456
# /kaggle/input/reuters/reuters/training/9415
# /kaggle/input/reuters/reuters/training/2298
# /kaggle/input/reuters/reuters/training/9159
# /kaggle/input/reuters/reuters/training/9479
# /kaggle/input/reuters/reuters/training/2225
# /kaggle/input/reuters/reuters/training/12973
# /kaggle/input/reuters/reuters/training/14298
# /kaggle/input/reuters/reuters/training/9947
# /kaggle/input/reuters/reuters/training/6875
# /kaggle/input/reuters/reuters/training/4245
# /kaggle/input/reuters/reuters/training/8972
# /kaggle/input/reuters/reuters/training/14177
# /kaggle/input/reuters/reuters/training/1292
# /kaggle/input/reuters/reuters/training/4038
# /kaggle/input/reuters/reuters/training/4747
# /kaggle/input/reuters/reuters/training/1688
# /kaggle/input/reuters/reuters/training/2767
# /kaggle/input/reuters/reuters/training/9312
# /kaggle/input/reuters/reuters/training/12209
# /kaggle/input/reuters/reuters/training/10406
# /kaggle/input/reuters/reuters/training/3389
# /kaggle/input/reuters/reuters/training/9163
# /kaggle/input/reuters/reuters/training/7817
# /kaggle/input/reuters/reuters/training/4658
# /kaggle/input/reuters/reuters/training/11831
# /kaggle/input/reuters/reuters/training/8167
# /kaggle/input/reuters/reuters/training/6065
# /kaggle/input/reuters/reuters/training/466
# /kaggle/input/reuters/reuters/training/9955
# /kaggle/input/reuters/reuters/training/1529
# /kaggle/input/reuters/reuters/training/9954
# /kaggle/input/reuters/reuters/training/12818
# /kaggle/input/reuters/reuters/training/9764
# /kaggle/input/reuters/reuters/training/494
# /kaggle/input/reuters/reuters/training/9195
# /kaggle/input/reuters/reuters/training/10989
# /kaggle/input/reuters/reuters/training/14297
# /kaggle/input/reuters/reuters/training/11469
# /kaggle/input/reuters/reuters/training/8178
# /kaggle/input/reuters/reuters/training/11571
# /kaggle/input/reuters/reuters/training/19
# /kaggle/input/reuters/reuters/training/12860
# /kaggle/input/reuters/reuters/training/2965
# /kaggle/input/reuters/reuters/training/199
# /kaggle/input/reuters/reuters/training/12174
# /kaggle/input/reuters/reuters/training/7628
# /kaggle/input/reuters/reuters/training/480
# /kaggle/input/reuters/reuters/training/9127
# /kaggle/input/reuters/reuters/training/7747
# /kaggle/input/reuters/reuters/training/2496
# /kaggle/input/reuters/reuters/training/121
# /kaggle/input/reuters/reuters/training/11962
# /kaggle/input/reuters/reuters/training/11085
# /kaggle/input/reuters/reuters/training/2266
# /kaggle/input/reuters/reuters/training/1982
# /kaggle/input/reuters/reuters/training/2497
# /kaggle/input/reuters/reuters/training/2933
# /kaggle/input/reuters/reuters/training/10563
# /kaggle/input/reuters/reuters/training/12423
# /kaggle/input/reuters/reuters/training/856
# /kaggle/input/reuters/reuters/training/12869
# /kaggle/input/reuters/reuters/training/13435
# /kaggle/input/reuters/reuters/training/695
# /kaggle/input/reuters/reuters/training/8961
# /kaggle/input/reuters/reuters/training/7590
# /kaggle/input/reuters/reuters/training/3463
# /kaggle/input/reuters/reuters/training/3766
# /kaggle/input/reuters/reuters/training/8665
# /kaggle/input/reuters/reuters/training/8016
# /kaggle/input/reuters/reuters/training/988
# /kaggle/input/reuters/reuters/training/5407
# /kaggle/input/reuters/reuters/training/8217
# /kaggle/input/reuters/reuters/training/10384
# /kaggle/input/reuters/reuters/training/1878
# /kaggle/input/reuters/reuters/training/849
# /kaggle/input/reuters/reuters/training/6296
# /kaggle/input/reuters/reuters/training/2711
# /kaggle/input/reuters/reuters/training/13189
# /kaggle/input/reuters/reuters/training/3910
# /kaggle/input/reuters/reuters/training/8925
# /kaggle/input/reuters/reuters/training/8050
# /kaggle/input/reuters/reuters/training/5190
# /kaggle/input/reuters/reuters/training/7749
# /kaggle/input/reuters/reuters/training/1649
# /kaggle/input/reuters/reuters/training/9161
# /kaggle/input/reuters/reuters/training/7352
# /kaggle/input/reuters/reuters/training/5899
# /kaggle/input/reuters/reuters/training/2020
# /kaggle/input/reuters/reuters/training/3394
# /kaggle/input/reuters/reuters/training/2542
# /kaggle/input/reuters/reuters/training/10291
# /kaggle/input/reuters/reuters/training/5617
# /kaggle/input/reuters/reuters/training/2604
# /kaggle/input/reuters/reuters/training/5338
# /kaggle/input/reuters/reuters/training/6000
# /kaggle/input/reuters/reuters/training/2012
# /kaggle/input/reuters/reuters/training/7395
# /kaggle/input/reuters/reuters/training/11587
# /kaggle/input/reuters/reuters/training/12841
# /kaggle/input/reuters/reuters/training/10025
# /kaggle/input/reuters/reuters/training/2544
# /kaggle/input/reuters/reuters/training/4249
# /kaggle/input/reuters/reuters/training/5082
# /kaggle/input/reuters/reuters/training/8534
# /kaggle/input/reuters/reuters/training/9829
# /kaggle/input/reuters/reuters/training/8209
# /kaggle/input/reuters/reuters/training/496
# /kaggle/input/reuters/reuters/training/10052
# /kaggle/input/reuters/reuters/training/11478
# /kaggle/input/reuters/reuters/training/3580
# /kaggle/input/reuters/reuters/training/743
# /kaggle/input/reuters/reuters/training/9217
# /kaggle/input/reuters/reuters/training/3057
# /kaggle/input/reuters/reuters/training/1044
# /kaggle/input/reuters/reuters/training/1715
# /kaggle/input/reuters/reuters/training/4599
# /kaggle/input/reuters/reuters/training/13105
# /kaggle/input/reuters/reuters/training/7359
# /kaggle/input/reuters/reuters/training/395
# /kaggle/input/reuters/reuters/training/1082
# /kaggle/input/reuters/reuters/training/8992
# /kaggle/input/reuters/reuters/training/884
# /kaggle/input/reuters/reuters/training/7111
# /kaggle/input/reuters/reuters/training/7510
# /kaggle/input/reuters/reuters/training/8247
# /kaggle/input/reuters/reuters/training/4576
# /kaggle/input/reuters/reuters/training/11984
# /kaggle/input/reuters/reuters/training/6205
# /kaggle/input/reuters/reuters/training/8218
# /kaggle/input/reuters/reuters/training/6486
# /kaggle/input/reuters/reuters/training/7286
# /kaggle/input/reuters/reuters/training/3668
# /kaggle/input/reuters/reuters/training/13552
# /kaggle/input/reuters/reuters/training/9532
# /kaggle/input/reuters/reuters/training/9385
# /kaggle/input/reuters/reuters/training/5276
# /kaggle/input/reuters/reuters/training/5762
# /kaggle/input/reuters/reuters/training/9051
# /kaggle/input/reuters/reuters/training/6840
# /kaggle/input/reuters/reuters/training/5722
# /kaggle/input/reuters/reuters/training/4328
# /kaggle/input/reuters/reuters/training/13054
# /kaggle/input/reuters/reuters/training/7930
# /kaggle/input/reuters/reuters/training/3467
# /kaggle/input/reuters/reuters/training/5260
# /kaggle/input/reuters/reuters/training/1192
# /kaggle/input/reuters/reuters/training/8676
# /kaggle/input/reuters/reuters/training/4255
# /kaggle/input/reuters/reuters/training/7954
# /kaggle/input/reuters/reuters/training/3037
# /kaggle/input/reuters/reuters/training/8984
# /kaggle/input/reuters/reuters/training/6234
# /kaggle/input/reuters/reuters/training/11335
# /kaggle/input/reuters/reuters/training/8428
# /kaggle/input/reuters/reuters/training/762
# /kaggle/input/reuters/reuters/training/1173
# /kaggle/input/reuters/reuters/training/12237
# /kaggle/input/reuters/reuters/training/10219
# /kaggle/input/reuters/reuters/training/5398
# /kaggle/input/reuters/reuters/training/4399
# /kaggle/input/reuters/reuters/training/6802
# /kaggle/input/reuters/reuters/training/6437
# /kaggle/input/reuters/reuters/training/5727
# /kaggle/input/reuters/reuters/training/4562
# /kaggle/input/reuters/reuters/training/8555
# /kaggle/input/reuters/reuters/training/10339
# /kaggle/input/reuters/reuters/training/2683
# /kaggle/input/reuters/reuters/training/3626
# /kaggle/input/reuters/reuters/training/4409
# /kaggle/input/reuters/reuters/training/6221
# /kaggle/input/reuters/reuters/training/10299
# /kaggle/input/reuters/reuters/training/3336
# /kaggle/input/reuters/reuters/training/11706
# /kaggle/input/reuters/reuters/training/10208
# /kaggle/input/reuters/reuters/training/1102
# /kaggle/input/reuters/reuters/training/22
# /kaggle/input/reuters/reuters/training/9982
# /kaggle/input/reuters/reuters/training/6199
# /kaggle/input/reuters/reuters/training/12303
# /kaggle/input/reuters/reuters/training/10621
# /kaggle/input/reuters/reuters/training/4177
# /kaggle/input/reuters/reuters/training/4904
# /kaggle/input/reuters/reuters/training/4212
# /kaggle/input/reuters/reuters/training/9202
# /kaggle/input/reuters/reuters/training/12437
# /kaggle/input/reuters/reuters/training/11795
# /kaggle/input/reuters/reuters/training/1312
# /kaggle/input/reuters/reuters/training/6496
# /kaggle/input/reuters/reuters/training/3858
# /kaggle/input/reuters/reuters/training/10867
# /kaggle/input/reuters/reuters/training/3622
# /kaggle/input/reuters/reuters/training/11621
# /kaggle/input/reuters/reuters/training/10321
# /kaggle/input/reuters/reuters/training/11722
# /kaggle/input/reuters/reuters/training/3046
# /kaggle/input/reuters/reuters/training/3026
# /kaggle/input/reuters/reuters/training/6347
# /kaggle/input/reuters/reuters/training/874
# /kaggle/input/reuters/reuters/training/1375
# /kaggle/input/reuters/reuters/training/4460
# /kaggle/input/reuters/reuters/training/330
# /kaggle/input/reuters/reuters/training/2877
# /kaggle/input/reuters/reuters/training/6311
# /kaggle/input/reuters/reuters/training/7983
# /kaggle/input/reuters/reuters/training/12885
# /kaggle/input/reuters/reuters/training/9748
# /kaggle/input/reuters/reuters/training/1461
# /kaggle/input/reuters/reuters/training/3808
# /kaggle/input/reuters/reuters/training/229
# /kaggle/input/reuters/reuters/training/2428
# /kaggle/input/reuters/reuters/training/10925
# /kaggle/input/reuters/reuters/training/6070
# /kaggle/input/reuters/reuters/training/9412
# /kaggle/input/reuters/reuters/training/4630
# /kaggle/input/reuters/reuters/training/11070
# /kaggle/input/reuters/reuters/training/13787
# /kaggle/input/reuters/reuters/training/2728
# /kaggle/input/reuters/reuters/training/7260
# /kaggle/input/reuters/reuters/training/7512
# /kaggle/input/reuters/reuters/training/1205
# /kaggle/input/reuters/reuters/training/4289
# /kaggle/input/reuters/reuters/training/5545
# /kaggle/input/reuters/reuters/training/4484
# /kaggle/input/reuters/reuters/training/519
# /kaggle/input/reuters/reuters/training/11083
# /kaggle/input/reuters/reuters/training/5555
# /kaggle/input/reuters/reuters/training/11773
# /kaggle/input/reuters/reuters/training/1178
# /kaggle/input/reuters/reuters/training/10449
# /kaggle/input/reuters/reuters/training/13172
# /kaggle/input/reuters/reuters/training/3098
# /kaggle/input/reuters/reuters/training/3105
# /kaggle/input/reuters/reuters/training/13269
# /kaggle/input/reuters/reuters/training/955
# /kaggle/input/reuters/reuters/training/1855
# /kaggle/input/reuters/reuters/training/4103
# /kaggle/input/reuters/reuters/training/6331
# /kaggle/input/reuters/reuters/training/7342
# /kaggle/input/reuters/reuters/training/6335
# /kaggle/input/reuters/reuters/training/6176
# /kaggle/input/reuters/reuters/training/3676
# /kaggle/input/reuters/reuters/training/11627
# /kaggle/input/reuters/reuters/training/4065
# /kaggle/input/reuters/reuters/training/11728
# /kaggle/input/reuters/reuters/training/7310
# /kaggle/input/reuters/reuters/training/7580
# /kaggle/input/reuters/reuters/training/14499
# /kaggle/input/reuters/reuters/training/12390
# /kaggle/input/reuters/reuters/training/1847
# /kaggle/input/reuters/reuters/training/7796
# /kaggle/input/reuters/reuters/training/6460
# /kaggle/input/reuters/reuters/training/12110
# /kaggle/input/reuters/reuters/training/9815
# /kaggle/input/reuters/reuters/training/2377
# /kaggle/input/reuters/reuters/training/9436
# /kaggle/input/reuters/reuters/training/1477
# /kaggle/input/reuters/reuters/training/7804
# /kaggle/input/reuters/reuters/training/12408
# /kaggle/input/reuters/reuters/training/14689
# /kaggle/input/reuters/reuters/training/9182
# /kaggle/input/reuters/reuters/training/1584
# /kaggle/input/reuters/reuters/training/5352
# /kaggle/input/reuters/reuters/training/5934
# /kaggle/input/reuters/reuters/training/5740
# /kaggle/input/reuters/reuters/training/10023
# /kaggle/input/reuters/reuters/training/2047
# /kaggle/input/reuters/reuters/training/3041
# /kaggle/input/reuters/reuters/training/5290
# /kaggle/input/reuters/reuters/training/9166
# /kaggle/input/reuters/reuters/training/1285
# /kaggle/input/reuters/reuters/training/12266
# /kaggle/input/reuters/reuters/training/4215
# /kaggle/input/reuters/reuters/training/11201
# /kaggle/input/reuters/reuters/training/9544
# /kaggle/input/reuters/reuters/training/4115
# /kaggle/input/reuters/reuters/training/10531
# /kaggle/input/reuters/reuters/training/10139
# /kaggle/input/reuters/reuters/training/9853
# /kaggle/input/reuters/reuters/training/4671
# /kaggle/input/reuters/reuters/training/2301
# /kaggle/input/reuters/reuters/training/2268
# /kaggle/input/reuters/reuters/training/11558
# /kaggle/input/reuters/reuters/training/12935
# /kaggle/input/reuters/reuters/training/7867
# /kaggle/input/reuters/reuters/training/253
# /kaggle/input/reuters/reuters/training/514
# /kaggle/input/reuters/reuters/training/9901
# /kaggle/input/reuters/reuters/training/11012
# /kaggle/input/reuters/reuters/training/10547
# /kaggle/input/reuters/reuters/training/5902
# /kaggle/input/reuters/reuters/training/1556
# /kaggle/input/reuters/reuters/training/8240
# /kaggle/input/reuters/reuters/training/12981
# /kaggle/input/reuters/reuters/training/9313
# /kaggle/input/reuters/reuters/training/10622
# /kaggle/input/reuters/reuters/training/4536
# /kaggle/input/reuters/reuters/training/8097
# /kaggle/input/reuters/reuters/training/4955
# /kaggle/input/reuters/reuters/training/10786
# /kaggle/input/reuters/reuters/training/12192
# /kaggle/input/reuters/reuters/training/9652
# /kaggle/input/reuters/reuters/training/406
# /kaggle/input/reuters/reuters/training/7297
# /kaggle/input/reuters/reuters/training/8331
# /kaggle/input/reuters/reuters/training/309
# /kaggle/input/reuters/reuters/training/851
# /kaggle/input/reuters/reuters/training/707
# /kaggle/input/reuters/reuters/training/4602
# /kaggle/input/reuters/reuters/training/4929
# /kaggle/input/reuters/reuters/training/1201
# /kaggle/input/reuters/reuters/training/8512
# /kaggle/input/reuters/reuters/training/164
# /kaggle/input/reuters/reuters/training/1071
# /kaggle/input/reuters/reuters/training/2479
# /kaggle/input/reuters/reuters/training/2151
# /kaggle/input/reuters/reuters/training/6441
# /kaggle/input/reuters/reuters/training/11251
# /kaggle/input/reuters/reuters/training/9497
# /kaggle/input/reuters/reuters/training/147
# /kaggle/input/reuters/reuters/training/12028
# /kaggle/input/reuters/reuters/training/1067
# /kaggle/input/reuters/reuters/training/2252
# /kaggle/input/reuters/reuters/training/6025
# /kaggle/input/reuters/reuters/training/9907
# /kaggle/input/reuters/reuters/training/10155
# /kaggle/input/reuters/reuters/training/5741
# /kaggle/input/reuters/reuters/training/145
# /kaggle/input/reuters/reuters/training/11783
# /kaggle/input/reuters/reuters/training/11668
# /kaggle/input/reuters/reuters/training/2048
# /kaggle/input/reuters/reuters/training/5575
# /kaggle/input/reuters/reuters/training/1164
# /kaggle/input/reuters/reuters/training/818
# /kaggle/input/reuters/reuters/training/2763
# /kaggle/input/reuters/reuters/training/3239
# /kaggle/input/reuters/reuters/training/13321
# /kaggle/input/reuters/reuters/training/1394
# /kaggle/input/reuters/reuters/training/213
# /kaggle/input/reuters/reuters/training/8156
# /kaggle/input/reuters/reuters/training/8546
# /kaggle/input/reuters/reuters/training/1797
# /kaggle/input/reuters/reuters/training/3898
# /kaggle/input/reuters/reuters/training/10218
# /kaggle/input/reuters/reuters/training/1519
# /kaggle/input/reuters/reuters/training/8854
# /kaggle/input/reuters/reuters/training/4282
# /kaggle/input/reuters/reuters/training/6346
# /kaggle/input/reuters/reuters/training/13950
# /kaggle/input/reuters/reuters/training/6102
# /kaggle/input/reuters/reuters/training/11177
# /kaggle/input/reuters/reuters/training/9592
# /kaggle/input/reuters/reuters/training/6464
# /kaggle/input/reuters/reuters/training/9527
# /kaggle/input/reuters/reuters/training/3748
# /kaggle/input/reuters/reuters/training/6960
# /kaggle/input/reuters/reuters/training/5003
# /kaggle/input/reuters/reuters/training/5974
# /kaggle/input/reuters/reuters/training/4094
# /kaggle/input/reuters/reuters/training/1498
# /kaggle/input/reuters/reuters/training/12974
# /kaggle/input/reuters/reuters/training/9381
# /kaggle/input/reuters/reuters/training/8089
# /kaggle/input/reuters/reuters/training/6280
# /kaggle/input/reuters/reuters/training/4509
# /kaggle/input/reuters/reuters/training/7997
# /kaggle/input/reuters/reuters/training/8100
# /kaggle/input/reuters/reuters/training/11617
# /kaggle/input/reuters/reuters/training/2067
# /kaggle/input/reuters/reuters/training/4138
# /kaggle/input/reuters/reuters/training/9346
# /kaggle/input/reuters/reuters/training/1347
# /kaggle/input/reuters/reuters/training/1496
# /kaggle/input/reuters/reuters/training/4988
# /kaggle/input/reuters/reuters/training/2456
# /kaggle/input/reuters/reuters/training/10527
# /kaggle/input/reuters/reuters/training/3420
# /kaggle/input/reuters/reuters/training/3338
# /kaggle/input/reuters/reuters/training/11386
# /kaggle/input/reuters/reuters/training/7319
# /kaggle/input/reuters/reuters/training/5778
# /kaggle/input/reuters/reuters/training/6293
# /kaggle/input/reuters/reuters/training/9525
# /kaggle/input/reuters/reuters/training/6180
# /kaggle/input/reuters/reuters/training/1381
# /kaggle/input/reuters/reuters/training/748
# /kaggle/input/reuters/reuters/training/11575
# /kaggle/input/reuters/reuters/training/6686
# /kaggle/input/reuters/reuters/training/5647
# /kaggle/input/reuters/reuters/training/11843
# /kaggle/input/reuters/reuters/training/11599
# /kaggle/input/reuters/reuters/training/10790
# /kaggle/input/reuters/reuters/training/1427
# /kaggle/input/reuters/reuters/training/7130
# /kaggle/input/reuters/reuters/training/13274
# /kaggle/input/reuters/reuters/training/6859
# /kaggle/input/reuters/reuters/training/9414
# /kaggle/input/reuters/reuters/training/2257
# /kaggle/input/reuters/reuters/training/1134
# /kaggle/input/reuters/reuters/training/4371
# /kaggle/input/reuters/reuters/training/4363
# /kaggle/input/reuters/reuters/training/995
# /kaggle/input/reuters/reuters/training/5960
# /kaggle/input/reuters/reuters/training/6373
# /kaggle/input/reuters/reuters/training/2049
# /kaggle/input/reuters/reuters/training/8026
# /kaggle/input/reuters/reuters/training/12076
# /kaggle/input/reuters/reuters/training/12389
# /kaggle/input/reuters/reuters/training/11767
# /kaggle/input/reuters/reuters/training/5264
# /kaggle/input/reuters/reuters/training/4765
# /kaggle/input/reuters/reuters/training/12795
# /kaggle/input/reuters/reuters/training/10112
# /kaggle/input/reuters/reuters/training/2389
# /kaggle/input/reuters/reuters/training/4240
# /kaggle/input/reuters/reuters/training/3951
# /kaggle/input/reuters/reuters/training/4455
# /kaggle/input/reuters/reuters/training/7217
# /kaggle/input/reuters/reuters/training/4775
# /kaggle/input/reuters/reuters/training/4938
# /kaggle/input/reuters/reuters/training/844
# /kaggle/input/reuters/reuters/training/8909
# /kaggle/input/reuters/reuters/training/9175
# /kaggle/input/reuters/reuters/training/7821
# /kaggle/input/reuters/reuters/training/532
# /kaggle/input/reuters/reuters/training/9014
# /kaggle/input/reuters/reuters/training/8614
# /kaggle/input/reuters/reuters/training/11300
# /kaggle/input/reuters/reuters/training/11664
# /kaggle/input/reuters/reuters/training/6776
# /kaggle/input/reuters/reuters/training/2602
# /kaggle/input/reuters/reuters/training/3977
# /kaggle/input/reuters/reuters/training/5657
# /kaggle/input/reuters/reuters/training/4488
# /kaggle/input/reuters/reuters/training/10682
# /kaggle/input/reuters/reuters/training/6853
# /kaggle/input/reuters/reuters/training/9752
# /kaggle/input/reuters/reuters/training/10262
# /kaggle/input/reuters/reuters/training/4573
# /kaggle/input/reuters/reuters/training/3569
# /kaggle/input/reuters/reuters/training/6127
# /kaggle/input/reuters/reuters/training/3931
# /kaggle/input/reuters/reuters/training/913
# /kaggle/input/reuters/reuters/training/10499
# /kaggle/input/reuters/reuters/training/9978
# /kaggle/input/reuters/reuters/training/10375
# /kaggle/input/reuters/reuters/training/11234
# /kaggle/input/reuters/reuters/training/10808
# /kaggle/input/reuters/reuters/training/9865
# /kaggle/input/reuters/reuters/training/6173
# /kaggle/input/reuters/reuters/training/12505
# /kaggle/input/reuters/reuters/training/12138
# /kaggle/input/reuters/reuters/training/11968
# /kaggle/input/reuters/reuters/training/8543
# /kaggle/input/reuters/reuters/training/4131
# /kaggle/input/reuters/reuters/training/9486
# /kaggle/input/reuters/reuters/training/7884
# /kaggle/input/reuters/reuters/training/8012
# /kaggle/input/reuters/reuters/training/336
# /kaggle/input/reuters/reuters/training/6047
# /kaggle/input/reuters/reuters/training/12517
# /kaggle/input/reuters/reuters/training/12786
# /kaggle/input/reuters/reuters/training/6404
# /kaggle/input/reuters/reuters/training/13194
# /kaggle/input/reuters/reuters/training/92
# /kaggle/input/reuters/reuters/training/11632
# /kaggle/input/reuters/reuters/training/3603
# /kaggle/input/reuters/reuters/training/9618
# /kaggle/input/reuters/reuters/training/1901
# /kaggle/input/reuters/reuters/training/4788
# /kaggle/input/reuters/reuters/training/3540
# /kaggle/input/reuters/reuters/training/8873
# /kaggle/input/reuters/reuters/training/11856
# /kaggle/input/reuters/reuters/training/8995
# /kaggle/input/reuters/reuters/training/7375
# /kaggle/input/reuters/reuters/training/3534
# /kaggle/input/reuters/reuters/training/5836
# /kaggle/input/reuters/reuters/training/11164
# /kaggle/input/reuters/reuters/training/11242
# /kaggle/input/reuters/reuters/training/10066
# /kaggle/input/reuters/reuters/training/1125
# /kaggle/input/reuters/reuters/training/7874
# /kaggle/input/reuters/reuters/training/1407
# /kaggle/input/reuters/reuters/training/9836
# /kaggle/input/reuters/reuters/training/11270
# /kaggle/input/reuters/reuters/training/9031
# /kaggle/input/reuters/reuters/training/4503
# /kaggle/input/reuters/reuters/training/303
# /kaggle/input/reuters/reuters/training/447
# /kaggle/input/reuters/reuters/training/14757
# /kaggle/input/reuters/reuters/training/9773
# /kaggle/input/reuters/reuters/training/12257
# /kaggle/input/reuters/reuters/training/2217
# /kaggle/input/reuters/reuters/training/939
# /kaggle/input/reuters/reuters/training/12127
# /kaggle/input/reuters/reuters/training/1842
# /kaggle/input/reuters/reuters/training/484
# /kaggle/input/reuters/reuters/training/11168
# /kaggle/input/reuters/reuters/training/13849
# /kaggle/input/reuters/reuters/training/7421
# /kaggle/input/reuters/reuters/training/8662
# /kaggle/input/reuters/reuters/training/311
# /kaggle/input/reuters/reuters/training/924
# /kaggle/input/reuters/reuters/training/9434
# /kaggle/input/reuters/reuters/training/7564
# /kaggle/input/reuters/reuters/training/3950
# /kaggle/input/reuters/reuters/training/13122
# /kaggle/input/reuters/reuters/training/1918
# /kaggle/input/reuters/reuters/training/11628
# /kaggle/input/reuters/reuters/training/12494
# /kaggle/input/reuters/reuters/training/10960
# /kaggle/input/reuters/reuters/training/3554
# /kaggle/input/reuters/reuters/training/2979
# /kaggle/input/reuters/reuters/training/12910
# /kaggle/input/reuters/reuters/training/1200
# /kaggle/input/reuters/reuters/training/6998
# /kaggle/input/reuters/reuters/training/10963
# /kaggle/input/reuters/reuters/training/8275
# /kaggle/input/reuters/reuters/training/10100
# /kaggle/input/reuters/reuters/training/1457
# /kaggle/input/reuters/reuters/training/5243
# /kaggle/input/reuters/reuters/training/3825
# /kaggle/input/reuters/reuters/training/14629
# /kaggle/input/reuters/reuters/training/4922
# /kaggle/input/reuters/reuters/training/11123
# /kaggle/input/reuters/reuters/training/1058
# /kaggle/input/reuters/reuters/training/2398
# /kaggle/input/reuters/reuters/training/11936
# /kaggle/input/reuters/reuters/training/7471
# /kaggle/input/reuters/reuters/training/1815
# /kaggle/input/reuters/reuters/training/9718
# /kaggle/input/reuters/reuters/training/5707
# /kaggle/input/reuters/reuters/training/13165
# /kaggle/input/reuters/reuters/training/2244
# /kaggle/input/reuters/reuters/training/4306
# /kaggle/input/reuters/reuters/training/1360
# /kaggle/input/reuters/reuters/training/3174
# /kaggle/input/reuters/reuters/training/3853
# /kaggle/input/reuters/reuters/training/9007
# /kaggle/input/reuters/reuters/training/2153
# /kaggle/input/reuters/reuters/training/6442
# /kaggle/input/reuters/reuters/training/5791
# /kaggle/input/reuters/reuters/training/7321
# /kaggle/input/reuters/reuters/training/10140
# /kaggle/input/reuters/reuters/training/12213
# /kaggle/input/reuters/reuters/training/9812
# /kaggle/input/reuters/reuters/training/6459
# /kaggle/input/reuters/reuters/training/1983
# /kaggle/input/reuters/reuters/training/7046
# /kaggle/input/reuters/reuters/training/254
# /kaggle/input/reuters/reuters/training/4178
# /kaggle/input/reuters/reuters/training/10153
# /kaggle/input/reuters/reuters/training/5469
# /kaggle/input/reuters/reuters/training/12549
# /kaggle/input/reuters/reuters/training/2608
# /kaggle/input/reuters/reuters/training/449
# /kaggle/input/reuters/reuters/training/4794
# /kaggle/input/reuters/reuters/training/6578
# /kaggle/input/reuters/reuters/training/13182
# /kaggle/input/reuters/reuters/training/12447
# /kaggle/input/reuters/reuters/training/972
# /kaggle/input/reuters/reuters/training/7247
# /kaggle/input/reuters/reuters/training/4680
# /kaggle/input/reuters/reuters/training/50
# /kaggle/input/reuters/reuters/training/7841
# /kaggle/input/reuters/reuters/training/5402
# /kaggle/input/reuters/reuters/training/4586
# /kaggle/input/reuters/reuters/training/1395
# /kaggle/input/reuters/reuters/training/5756
# /kaggle/input/reuters/reuters/training/8190
# /kaggle/input/reuters/reuters/training/3990
# /kaggle/input/reuters/reuters/training/4632
# /kaggle/input/reuters/reuters/training/5392
# /kaggle/input/reuters/reuters/training/3777
# /kaggle/input/reuters/reuters/training/2271
# /kaggle/input/reuters/reuters/training/2508
# /kaggle/input/reuters/reuters/training/5287
# /kaggle/input/reuters/reuters/training/7669
# /kaggle/input/reuters/reuters/training/4346
# /kaggle/input/reuters/reuters/training/10729
# /kaggle/input/reuters/reuters/training/12530
# /kaggle/input/reuters/reuters/training/1174
# /kaggle/input/reuters/reuters/training/23
# /kaggle/input/reuters/reuters/training/13095
# /kaggle/input/reuters/reuters/training/11789
# /kaggle/input/reuters/reuters/training/1602
# /kaggle/input/reuters/reuters/training/4959
# /kaggle/input/reuters/reuters/training/10619
# /kaggle/input/reuters/reuters/training/10280
# /kaggle/input/reuters/reuters/training/6295
# /kaggle/input/reuters/reuters/training/3094
# /kaggle/input/reuters/reuters/training/5329
# /kaggle/input/reuters/reuters/training/6898
# /kaggle/input/reuters/reuters/training/1128
# /kaggle/input/reuters/reuters/training/9557
# /kaggle/input/reuters/reuters/training/8335
# /kaggle/input/reuters/reuters/training/11598
# /kaggle/input/reuters/reuters/training/10561
# /kaggle/input/reuters/reuters/training/10068
# /kaggle/input/reuters/reuters/training/9893
# /kaggle/input/reuters/reuters/training/3721
# /kaggle/input/reuters/reuters/training/10341
# /kaggle/input/reuters/reuters/training/7726
# /kaggle/input/reuters/reuters/training/1203
# /kaggle/input/reuters/reuters/training/12258
# /kaggle/input/reuters/reuters/training/9162
# /kaggle/input/reuters/reuters/training/10641
# /kaggle/input/reuters/reuters/training/2907
# /kaggle/input/reuters/reuters/training/3198
# /kaggle/input/reuters/reuters/training/3468
# /kaggle/input/reuters/reuters/training/8023
# /kaggle/input/reuters/reuters/training/87
# /kaggle/input/reuters/reuters/training/2635
# /kaggle/input/reuters/reuters/training/1577
# /kaggle/input/reuters/reuters/training/6738
# /kaggle/input/reuters/reuters/training/7934
# /kaggle/input/reuters/reuters/training/9894
# /kaggle/input/reuters/reuters/training/9129
# /kaggle/input/reuters/reuters/training/4411
# /kaggle/input/reuters/reuters/training/4662
# /kaggle/input/reuters/reuters/training/6873
# /kaggle/input/reuters/reuters/training/7679
# /kaggle/input/reuters/reuters/training/11007
# /kaggle/input/reuters/reuters/training/3607
# /kaggle/input/reuters/reuters/training/11006
# /kaggle/input/reuters/reuters/training/4892
# /kaggle/input/reuters/reuters/training/9465
# /kaggle/input/reuters/reuters/training/4275
# /kaggle/input/reuters/reuters/training/11633
# /kaggle/input/reuters/reuters/training/11958
# /kaggle/input/reuters/reuters/training/689
# /kaggle/input/reuters/reuters/training/13949
# /kaggle/input/reuters/reuters/training/10901
# /kaggle/input/reuters/reuters/training/12891
# /kaggle/input/reuters/reuters/training/9137
# /kaggle/input/reuters/reuters/training/8802
# /kaggle/input/reuters/reuters/training/352
# /kaggle/input/reuters/reuters/training/547
# /kaggle/input/reuters/reuters/training/6638
# /kaggle/input/reuters/reuters/training/5511
# /kaggle/input/reuters/reuters/training/7488
# /kaggle/input/reuters/reuters/training/10300
# /kaggle/input/reuters/reuters/training/9076
# /kaggle/input/reuters/reuters/training/7606
# /kaggle/input/reuters/reuters/training/7010
# /kaggle/input/reuters/reuters/training/12849
# /kaggle/input/reuters/reuters/training/7498
# /kaggle/input/reuters/reuters/training/11945
# /kaggle/input/reuters/reuters/training/187
# /kaggle/input/reuters/reuters/training/4142
# /kaggle/input/reuters/reuters/training/12453
# /kaggle/input/reuters/reuters/training/2944
# /kaggle/input/reuters/reuters/training/3598
# /kaggle/input/reuters/reuters/training/12275
# /kaggle/input/reuters/reuters/training/10
# /kaggle/input/reuters/reuters/training/8349
# /kaggle/input/reuters/reuters/training/5344
# /kaggle/input/reuters/reuters/training/7205
# /kaggle/input/reuters/reuters/training/5556
# /kaggle/input/reuters/reuters/training/8219
# /kaggle/input/reuters/reuters/training/4636
# /kaggle/input/reuters/reuters/training/4810
# /kaggle/input/reuters/reuters/training/12996
# /kaggle/input/reuters/reuters/training/9689
# /kaggle/input/reuters/reuters/training/4833
# /kaggle/input/reuters/reuters/training/11775
# /kaggle/input/reuters/reuters/training/3367
# /kaggle/input/reuters/reuters/training/3191
# /kaggle/input/reuters/reuters/training/6814
# /kaggle/input/reuters/reuters/training/6539
# /kaggle/input/reuters/reuters/training/3303
# /kaggle/input/reuters/reuters/training/4776
# /kaggle/input/reuters/reuters/training/2819
# /kaggle/input/reuters/reuters/training/10322
# /kaggle/input/reuters/reuters/training/9003
# /kaggle/input/reuters/reuters/training/7603
# /kaggle/input/reuters/reuters/training/7189
# /kaggle/input/reuters/reuters/training/7528
# /kaggle/input/reuters/reuters/training/2187
# /kaggle/input/reuters/reuters/training/10742
# /kaggle/input/reuters/reuters/training/1871
# /kaggle/input/reuters/reuters/training/9134
# /kaggle/input/reuters/reuters/training/8603
# /kaggle/input/reuters/reuters/training/925
# /kaggle/input/reuters/reuters/training/1634
# /kaggle/input/reuters/reuters/training/14736
# /kaggle/input/reuters/reuters/training/9807
# /kaggle/input/reuters/reuters/training/9837
# /kaggle/input/reuters/reuters/training/1382
# /kaggle/input/reuters/reuters/training/7831
# /kaggle/input/reuters/reuters/training/8746
# /kaggle/input/reuters/reuters/training/11597
# /kaggle/input/reuters/reuters/training/7136
# /kaggle/input/reuters/reuters/training/10319
# /kaggle/input/reuters/reuters/training/2172
# /kaggle/input/reuters/reuters/training/7674
# /kaggle/input/reuters/reuters/training/7614
# /kaggle/input/reuters/reuters/training/13197
# /kaggle/input/reuters/reuters/training/7068
# /kaggle/input/reuters/reuters/training/10650
# /kaggle/input/reuters/reuters/training/2095
# /kaggle/input/reuters/reuters/training/14207
# /kaggle/input/reuters/reuters/training/1252
# /kaggle/input/reuters/reuters/training/14752
# /kaggle/input/reuters/reuters/training/2886
# /kaggle/input/reuters/reuters/training/2281
# /kaggle/input/reuters/reuters/training/5128
# /kaggle/input/reuters/reuters/training/6282
# /kaggle/input/reuters/reuters/training/5447
# /kaggle/input/reuters/reuters/training/1787
# /kaggle/input/reuters/reuters/training/1493
# /kaggle/input/reuters/reuters/training/9115
# /kaggle/input/reuters/reuters/training/6672
# /kaggle/input/reuters/reuters/training/3884
# /kaggle/input/reuters/reuters/training/9869
# /kaggle/input/reuters/reuters/training/1072
# /kaggle/input/reuters/reuters/training/7443
# /kaggle/input/reuters/reuters/training/12853
# /kaggle/input/reuters/reuters/training/12563
# /kaggle/input/reuters/reuters/training/5
# /kaggle/input/reuters/reuters/training/14028
# /kaggle/input/reuters/reuters/training/1108
# /kaggle/input/reuters/reuters/training/9582
# /kaggle/input/reuters/reuters/training/11257
# /kaggle/input/reuters/reuters/training/3411
# /kaggle/input/reuters/reuters/training/372
# /kaggle/input/reuters/reuters/training/14427
# /kaggle/input/reuters/reuters/training/9196
# /kaggle/input/reuters/reuters/training/1619
# /kaggle/input/reuters/reuters/training/7917
# /kaggle/input/reuters/reuters/training/1885
# /kaggle/input/reuters/reuters/training/2130
# /kaggle/input/reuters/reuters/training/4281
# /kaggle/input/reuters/reuters/training/8112
# /kaggle/input/reuters/reuters/training/14603
# /kaggle/input/reuters/reuters/training/4165
# /kaggle/input/reuters/reuters/training/10834
# /kaggle/input/reuters/reuters/training/3273
# /kaggle/input/reuters/reuters/training/9111
# /kaggle/input/reuters/reuters/training/8835
# /kaggle/input/reuters/reuters/training/8935
# /kaggle/input/reuters/reuters/training/408
# /kaggle/input/reuters/reuters/training/3469
# /kaggle/input/reuters/reuters/training/2672
# /kaggle/input/reuters/reuters/training/8130
# /kaggle/input/reuters/reuters/training/3246
# /kaggle/input/reuters/reuters/training/2583
# /kaggle/input/reuters/reuters/training/6913
# /kaggle/input/reuters/reuters/training/11850
# /kaggle/input/reuters/reuters/training/7640
# /kaggle/input/reuters/reuters/training/11825
# /kaggle/input/reuters/reuters/training/10620
# /kaggle/input/reuters/reuters/training/12538
# /kaggle/input/reuters/reuters/training/8109
# /kaggle/input/reuters/reuters/training/11539
# /kaggle/input/reuters/reuters/training/1622
# /kaggle/input/reuters/reuters/training/5288
# /kaggle/input/reuters/reuters/training/2961
# /kaggle/input/reuters/reuters/training/11444
# /kaggle/input/reuters/reuters/training/3897
# /kaggle/input/reuters/reuters/training/1378
# /kaggle/input/reuters/reuters/training/13393
# /kaggle/input/reuters/reuters/training/3579
# /kaggle/input/reuters/reuters/training/11126
# /kaggle/input/reuters/reuters/training/3933
# /kaggle/input/reuters/reuters/training/9197
# /kaggle/input/reuters/reuters/training/8491
# /kaggle/input/reuters/reuters/training/5780
# /kaggle/input/reuters/reuters/training/5228
# /kaggle/input/reuters/reuters/training/3744
# /kaggle/input/reuters/reuters/training/10928
# /kaggle/input/reuters/reuters/training/2482
# /kaggle/input/reuters/reuters/training/9124
# /kaggle/input/reuters/reuters/training/2827
# /kaggle/input/reuters/reuters/training/2691
# /kaggle/input/reuters/reuters/training/3762
# /kaggle/input/reuters/reuters/training/13072
# /kaggle/input/reuters/reuters/training/6675
# /kaggle/input/reuters/reuters/training/3348
# /kaggle/input/reuters/reuters/training/1460
# /kaggle/input/reuters/reuters/training/9768
# /kaggle/input/reuters/reuters/training/7155
# /kaggle/input/reuters/reuters/training/2092
# /kaggle/input/reuters/reuters/training/14354
# /kaggle/input/reuters/reuters/training/1273
# /kaggle/input/reuters/reuters/training/9936
# /kaggle/input/reuters/reuters/training/1185
# /kaggle/input/reuters/reuters/training/6399
# /kaggle/input/reuters/reuters/training/14539
# /kaggle/input/reuters/reuters/training/11663
# /kaggle/input/reuters/reuters/training/11545
# /kaggle/input/reuters/reuters/training/13244
# /kaggle/input/reuters/reuters/training/5421
# /kaggle/input/reuters/reuters/training/3267
# /kaggle/input/reuters/reuters/training/9110
# /kaggle/input/reuters/reuters/training/2529
# /kaggle/input/reuters/reuters/training/1626
# /kaggle/input/reuters/reuters/training/2116
# /kaggle/input/reuters/reuters/training/3512
# /kaggle/input/reuters/reuters/training/3061
# /kaggle/input/reuters/reuters/training/3318
# /kaggle/input/reuters/reuters/training/10505
# /kaggle/input/reuters/reuters/training/10097
# /kaggle/input/reuters/reuters/training/6893
# /kaggle/input/reuters/reuters/training/2697
# /kaggle/input/reuters/reuters/training/7036
# /kaggle/input/reuters/reuters/training/6368
# /kaggle/input/reuters/reuters/training/3747
# /kaggle/input/reuters/reuters/training/14091
# /kaggle/input/reuters/reuters/training/4278
# /kaggle/input/reuters/reuters/training/6058
# /kaggle/input/reuters/reuters/training/11396
# /kaggle/input/reuters/reuters/training/2004
# /kaggle/input/reuters/reuters/training/9090
# /kaggle/input/reuters/reuters/training/5935
# /kaggle/input/reuters/reuters/training/3514
# /kaggle/input/reuters/reuters/training/3690
# /kaggle/input/reuters/reuters/training/12383
# /kaggle/input/reuters/reuters/training/11977
# /kaggle/input/reuters/reuters/training/10529
# /kaggle/input/reuters/reuters/training/1767
# /kaggle/input/reuters/reuters/training/5379
# /kaggle/input/reuters/reuters/training/4772
# /kaggle/input/reuters/reuters/training/2964
# /kaggle/input/reuters/reuters/training/13003
# /kaggle/input/reuters/reuters/training/2410
# /kaggle/input/reuters/reuters/training/8326
# /kaggle/input/reuters/reuters/training/14722
# /kaggle/input/reuters/reuters/training/13834
# /kaggle/input/reuters/reuters/training/11064
# /kaggle/input/reuters/reuters/training/10324
# /kaggle/input/reuters/reuters/training/2549
# /kaggle/input/reuters/reuters/training/12195
# /kaggle/input/reuters/reuters/training/10616
# /kaggle/input/reuters/reuters/training/4366
# /kaggle/input/reuters/reuters/training/8795
# /kaggle/input/reuters/reuters/training/4012
# /kaggle/input/reuters/reuters/training/6743
# /kaggle/input/reuters/reuters/training/13225
# /kaggle/input/reuters/reuters/training/7079
# /kaggle/input/reuters/reuters/training/5132
# /kaggle/input/reuters/reuters/training/405
# /kaggle/input/reuters/reuters/training/1961
# /kaggle/input/reuters/reuters/training/5630
# /kaggle/input/reuters/reuters/training/1135
# /kaggle/input/reuters/reuters/training/1011
# /kaggle/input/reuters/reuters/training/7541
# /kaggle/input/reuters/reuters/training/2768
# /kaggle/input/reuters/reuters/training/10255
# /kaggle/input/reuters/reuters/training/7190
# /kaggle/input/reuters/reuters/training/8600
# /kaggle/input/reuters/reuters/training/9261
# /kaggle/input/reuters/reuters/training/8004
# /kaggle/input/reuters/reuters/training/11855
# /kaggle/input/reuters/reuters/training/5692
# /kaggle/input/reuters/reuters/training/3786
# /kaggle/input/reuters/reuters/training/6108
# /kaggle/input/reuters/reuters/training/2590
# /kaggle/input/reuters/reuters/training/435
# /kaggle/input/reuters/reuters/training/2864
# /kaggle/input/reuters/reuters/training/3157
# /kaggle/input/reuters/reuters/training/8125
# /kaggle/input/reuters/reuters/training/2312
# /kaggle/input/reuters/reuters/training/11287
# /kaggle/input/reuters/reuters/training/10238
# /kaggle/input/reuters/reuters/training/1759
# /kaggle/input/reuters/reuters/training/10076
# /kaggle/input/reuters/reuters/training/8080
# /kaggle/input/reuters/reuters/training/9755
# /kaggle/input/reuters/reuters/training/2913
# /kaggle/input/reuters/reuters/training/2386
# /kaggle/input/reuters/reuters/training/10857
# /kaggle/input/reuters/reuters/training/900
# /kaggle/input/reuters/reuters/training/3667
# /kaggle/input/reuters/reuters/training/11665
# /kaggle/input/reuters/reuters/training/8253
# /kaggle/input/reuters/reuters/training/5142
# /kaggle/input/reuters/reuters/training/2007
# /kaggle/input/reuters/reuters/training/6856
# /kaggle/input/reuters/reuters/training/10891
# /kaggle/input/reuters/reuters/training/13842
# /kaggle/input/reuters/reuters/training/6352
# /kaggle/input/reuters/reuters/training/12164
# /kaggle/input/reuters/reuters/training/13717
# /kaggle/input/reuters/reuters/training/5439
# /kaggle/input/reuters/reuters/training/11915
# /kaggle/input/reuters/reuters/training/5212
# /kaggle/input/reuters/reuters/training/10357
# /kaggle/input/reuters/reuters/training/2393
# /kaggle/input/reuters/reuters/training/915
# /kaggle/input/reuters/reuters/training/4537
# /kaggle/input/reuters/reuters/training/36
# /kaggle/input/reuters/reuters/training/4687
# /kaggle/input/reuters/reuters/training/5317
# /kaggle/input/reuters/reuters/training/4814
# /kaggle/input/reuters/reuters/training/1277
# /kaggle/input/reuters/reuters/training/9101
# /kaggle/input/reuters/reuters/training/11768
# /kaggle/input/reuters/reuters/training/1040
# /kaggle/input/reuters/reuters/training/4148
# /kaggle/input/reuters/reuters/training/11752
# /kaggle/input/reuters/reuters/training/1299
# /kaggle/input/reuters/reuters/training/6425
# /kaggle/input/reuters/reuters/training/4920
# /kaggle/input/reuters/reuters/training/5241
# /kaggle/input/reuters/reuters/training/2749
# /kaggle/input/reuters/reuters/training/1291
# /kaggle/input/reuters/reuters/training/7953
# /kaggle/input/reuters/reuters/training/2500
# /kaggle/input/reuters/reuters/training/10073
# /kaggle/input/reuters/reuters/training/9792
# /kaggle/input/reuters/reuters/training/7765
# /kaggle/input/reuters/reuters/training/1980
# /kaggle/input/reuters/reuters/training/11163
# /kaggle/input/reuters/reuters/training/2956
# ...
# /kaggle/input/reuters/reuters/test/17618
# /kaggle/input/reuters/reuters/test/20828
# /kaggle/input/reuters/reuters/test/20494
# /kaggle/input/reuters/reuters/test/16161
# /kaggle/input/reuters/reuters/test/14861
# /kaggle/input/reuters/reuters/test/15300
# /kaggle/input/reuters/reuters/test/21303
# /kaggle/input/reuters/reuters/test/19388
# /kaggle/input/reuters/reuters/test/19297
# /kaggle/input/reuters/reuters/test/19572
# /kaggle/input/reuters/reuters/test/19075
# /kaggle/input/reuters/reuters/test/19037
# /kaggle/input/reuters/reuters/test/16428
# /kaggle/input/reuters/reuters/test/15233
# /kaggle/input/reuters/reuters/test/14931
# /kaggle/input/reuters/reuters/test/19501
# /kaggle/input/reuters/reuters/test/19571
# /kaggle/input/reuters/reuters/test/18692
# /kaggle/input/reuters/reuters/test/16118
# /kaggle/input/reuters/reuters/test/15132
# /kaggle/input/reuters/reuters/test/20299
# /kaggle/input/reuters/reuters/test/17750
# /kaggle/input/reuters/reuters/test/21044
# /kaggle/input/reuters/reuters/test/19982
# /kaggle/input/reuters/reuters/test/20366
# /kaggle/input/reuters/reuters/test/18523
# /kaggle/input/reuters/reuters/test/16600
# /kaggle/input/reuters/reuters/test/16593
# /kaggle/input/reuters/reuters/test/20557
# /kaggle/input/reuters/reuters/test/20711
# /kaggle/input/reuters/reuters/test/20248
# /kaggle/input/reuters/reuters/test/15708
# /kaggle/input/reuters/reuters/test/15154
# /kaggle/input/reuters/reuters/test/20973
# /kaggle/input/reuters/reuters/test/15380
# /kaggle/input/reuters/reuters/test/20216
# /kaggle/input/reuters/reuters/test/19223
# /kaggle/input/reuters/reuters/test/18093
# /kaggle/input/reuters/reuters/test/16461
# /kaggle/input/reuters/reuters/test/20304
# /kaggle/input/reuters/reuters/test/18213
# /kaggle/input/reuters/reuters/test/18667
# /kaggle/input/reuters/reuters/test/18493
# /kaggle/input/reuters/reuters/test/15800
# /kaggle/input/reuters/reuters/test/19419
# /kaggle/input/reuters/reuters/test/16320
# /kaggle/input/reuters/reuters/test/16163
# /kaggle/input/reuters/reuters/test/15667
# /kaggle/input/reuters/reuters/test/20485
# /kaggle/input/reuters/reuters/test/18101
# /kaggle/input/reuters/reuters/test/15979
# /kaggle/input/reuters/reuters/test/16645
# /kaggle/input/reuters/reuters/test/17872
# /kaggle/input/reuters/reuters/test/15726
# /kaggle/input/reuters/reuters/test/16395
# /kaggle/input/reuters/reuters/test/15415
# /kaggle/input/reuters/reuters/test/16106
# /kaggle/input/reuters/reuters/test/20651
# /kaggle/input/reuters/reuters/test/15281
# /kaggle/input/reuters/reuters/test/18085
# /kaggle/input/reuters/reuters/test/16762
# /kaggle/input/reuters/reuters/test/19409
# /kaggle/input/reuters/reuters/test/19545
# /kaggle/input/reuters/reuters/test/20930
# /kaggle/input/reuters/reuters/test/16112
# /kaggle/input/reuters/reuters/test/15856
# /kaggle/input/reuters/reuters/test/14922
# /kaggle/input/reuters/reuters/test/20308
# /kaggle/input/reuters/reuters/test/20374
# /kaggle/input/reuters/reuters/test/17867
# /kaggle/input/reuters/reuters/test/15069
# /kaggle/input/reuters/reuters/test/16202
# /kaggle/input/reuters/reuters/test/15854
# /kaggle/input/reuters/reuters/test/20381
# /kaggle/input/reuters/reuters/test/15171
# /kaggle/input/reuters/reuters/test/20223
# /kaggle/input/reuters/reuters/test/20862
# /kaggle/input/reuters/reuters/test/16219
# /kaggle/input/reuters/reuters/test/18038
# /kaggle/input/reuters/reuters/test/19373
# /kaggle/input/reuters/reuters/test/15092
# /kaggle/input/reuters/reuters/test/15367
# /kaggle/input/reuters/reuters/test/16269
# /kaggle/input/reuters/reuters/test/19869
# /kaggle/input/reuters/reuters/test/15246
# /kaggle/input/reuters/reuters/test/15580
# /kaggle/input/reuters/reuters/test/21292
# /kaggle/input/reuters/reuters/test/18530
# /kaggle/input/reuters/reuters/test/20868
# /kaggle/input/reuters/reuters/test/19344
# /kaggle/input/reuters/reuters/test/16440
# /kaggle/input/reuters/reuters/test/18751
# /kaggle/input/reuters/reuters/test/16604
# /kaggle/input/reuters/reuters/test/19541
# /kaggle/input/reuters/reuters/test/16420
# /kaggle/input/reuters/reuters/test/20400
# /kaggle/input/reuters/reuters/test/15593
# /kaggle/input/reuters/reuters/test/15897
# /kaggle/input/reuters/reuters/test/19406
# /kaggle/input/reuters/reuters/test/19803
# /kaggle/input/reuters/reuters/test/16023
# /kaggle/input/reuters/reuters/test/15097
# /kaggle/input/reuters/reuters/test/20432
# /kaggle/input/reuters/reuters/test/20187
# /kaggle/input/reuters/reuters/test/20016
# /kaggle/input/reuters/reuters/test/15522
# /kaggle/input/reuters/reuters/test/14911
# /kaggle/input/reuters/reuters/test/21414
# /kaggle/input/reuters/reuters/test/17563
# /kaggle/input/reuters/reuters/test/17753
# /kaggle/input/reuters/reuters/test/18148
# /kaggle/input/reuters/reuters/test/16808
# /kaggle/input/reuters/reuters/test/15352
# /kaggle/input/reuters/reuters/test/19866
# /kaggle/input/reuters/reuters/test/16223
# /kaggle/input/reuters/reuters/test/15767
# /kaggle/input/reuters/reuters/test/20564
# /kaggle/input/reuters/reuters/test/16173
# /kaggle/input/reuters/reuters/test/14985
# /kaggle/input/reuters/reuters/test/19286
# /kaggle/input/reuters/reuters/test/18906
# /kaggle/input/reuters/reuters/test/15906
# /kaggle/input/reuters/reuters/test/18302
# /kaggle/input/reuters/reuters/test/21277
# /kaggle/input/reuters/reuters/test/15322
# /kaggle/input/reuters/reuters/test/19368
# /kaggle/input/reuters/reuters/test/17932
# /kaggle/input/reuters/reuters/test/20081
# /kaggle/input/reuters/reuters/test/16650
# /kaggle/input/reuters/reuters/test/18564
# /kaggle/input/reuters/reuters/test/15927
# /kaggle/input/reuters/reuters/test/16162
# /kaggle/input/reuters/reuters/test/19360
# /kaggle/input/reuters/reuters/test/21253
# /kaggle/input/reuters/reuters/test/20678
# /kaggle/input/reuters/reuters/test/18748
# /kaggle/input/reuters/reuters/test/15832
# /kaggle/input/reuters/reuters/test/19631
# /kaggle/input/reuters/reuters/test/15717
# /kaggle/input/reuters/reuters/test/17620
# /kaggle/input/reuters/reuters/test/15295
# /kaggle/input/reuters/reuters/test/15483
# /kaggle/input/reuters/reuters/test/18071
# /kaggle/input/reuters/reuters/test/19657
# /kaggle/input/reuters/reuters/test/15394
# /kaggle/input/reuters/reuters/test/20332
# /kaggle/input/reuters/reuters/test/20936
# /kaggle/input/reuters/reuters/test/20606
# /kaggle/input/reuters/reuters/test/15501
# /kaggle/input/reuters/reuters/test/16763
# /kaggle/input/reuters/reuters/test/15417
# /kaggle/input/reuters/reuters/test/16610
# /kaggle/input/reuters/reuters/test/16158
# /kaggle/input/reuters/reuters/test/19403
# /kaggle/input/reuters/reuters/test/20778
# /kaggle/input/reuters/reuters/test/19169
# /kaggle/input/reuters/reuters/test/18242
# /kaggle/input/reuters/reuters/test/15790
# /kaggle/input/reuters/reuters/test/18686
# /kaggle/input/reuters/reuters/test/16893
# /kaggle/input/reuters/reuters/test/15916
# /kaggle/input/reuters/reuters/test/19464
# /kaggle/input/reuters/reuters/test/15185
# /kaggle/input/reuters/reuters/test/21301
# /kaggle/input/reuters/reuters/test/15870
# /kaggle/input/reuters/reuters/test/19844
# /kaggle/input/reuters/reuters/test/18569
# /kaggle/input/reuters/reuters/test/15583
# /kaggle/input/reuters/reuters/test/15033
# /kaggle/input/reuters/reuters/test/15383
# /kaggle/input/reuters/reuters/test/19860
# /kaggle/input/reuters/reuters/test/16424
# /kaggle/input/reuters/reuters/test/15949
# /kaggle/input/reuters/reuters/test/20181
# /kaggle/input/reuters/reuters/test/19170
# /kaggle/input/reuters/reuters/test/15829
# /kaggle/input/reuters/reuters/test/16400
# /kaggle/input/reuters/reuters/test/21479
# /kaggle/input/reuters/reuters/test/20302
# /kaggle/input/reuters/reuters/test/17443
# /kaggle/input/reuters/reuters/test/18922
# /kaggle/input/reuters/reuters/test/17886
# /kaggle/input/reuters/reuters/test/15329
# /kaggle/input/reuters/reuters/test/21211
# /kaggle/input/reuters/reuters/test/20869
# /kaggle/input/reuters/reuters/test/21354
# /kaggle/input/reuters/reuters/test/16706
# /kaggle/input/reuters/reuters/test/16380
# /kaggle/input/reuters/reuters/test/15460
# /kaggle/input/reuters/reuters/test/18911
# /kaggle/input/reuters/reuters/test/18873
# /kaggle/input/reuters/reuters/test/21051
# /kaggle/input/reuters/reuters/test/16538
# /kaggle/input/reuters/reuters/test/16443
# /kaggle/input/reuters/reuters/test/16360
# /kaggle/input/reuters/reuters/test/16004
# /kaggle/input/reuters/reuters/test/21166
# /kaggle/input/reuters/reuters/test/18910
# /kaggle/input/reuters/reuters/test/20208
# /kaggle/input/reuters/reuters/test/17943
# /kaggle/input/reuters/reuters/test/16299
# /kaggle/input/reuters/reuters/test/17986
# /kaggle/input/reuters/reuters/test/20226
# /kaggle/input/reuters/reuters/test/15045
# /kaggle/input/reuters/reuters/test/21568
# /kaggle/input/reuters/reuters/test/17763
# /kaggle/input/reuters/reuters/test/19668
# /kaggle/input/reuters/reuters/test/15427
# /kaggle/input/reuters/reuters/test/20879
# /kaggle/input/reuters/reuters/test/18275
# /kaggle/input/reuters/reuters/test/19271
# /kaggle/input/reuters/reuters/test/19411
# /kaggle/input/reuters/reuters/test/21163
# /kaggle/input/reuters/reuters/test/15119
# /kaggle/input/reuters/reuters/test/21492
# /kaggle/input/reuters/reuters/test/16365
# /kaggle/input/reuters/reuters/test/16518
# /kaggle/input/reuters/reuters/test/19378
# /kaggle/input/reuters/reuters/test/15449
# /kaggle/input/reuters/reuters/test/20793
# /kaggle/input/reuters/reuters/test/21096
# /kaggle/input/reuters/reuters/test/18592
# /kaggle/input/reuters/reuters/test/19152
# /kaggle/input/reuters/reuters/test/19790
# /kaggle/input/reuters/reuters/test/21298
# /kaggle/input/reuters/reuters/test/20944
# /kaggle/input/reuters/reuters/test/19649
# /kaggle/input/reuters/reuters/test/17913
# /kaggle/input/reuters/reuters/test/16388
# /kaggle/input/reuters/reuters/test/15865
# /kaggle/input/reuters/reuters/test/18943
# /kaggle/input/reuters/reuters/test/20324
# /kaggle/input/reuters/reuters/test/17827
# /kaggle/input/reuters/reuters/test/15548
# /kaggle/input/reuters/reuters/test/21109
# /kaggle/input/reuters/reuters/test/19489
# /kaggle/input/reuters/reuters/test/18524
# /kaggle/input/reuters/reuters/test/19506
# /kaggle/input/reuters/reuters/test/21321
# /kaggle/input/reuters/reuters/test/18497
# /kaggle/input/reuters/reuters/test/21308
# /kaggle/input/reuters/reuters/test/16564
# /kaggle/input/reuters/reuters/test/21474
# /kaggle/input/reuters/reuters/test/17543
# /kaggle/input/reuters/reuters/test/15984
# /kaggle/input/reuters/reuters/test/20008
# /kaggle/input/reuters/reuters/test/19761
# /kaggle/input/reuters/reuters/test/19983
# /kaggle/input/reuters/reuters/test/21416
# /kaggle/input/reuters/reuters/test/15162
# /kaggle/input/reuters/reuters/test/18997
# /kaggle/input/reuters/reuters/test/20382
# /kaggle/input/reuters/reuters/test/18108
# /kaggle/input/reuters/reuters/test/19069
# /kaggle/input/reuters/reuters/test/18858
# /kaggle/input/reuters/reuters/test/21233
# /kaggle/input/reuters/reuters/test/15939
# /kaggle/input/reuters/reuters/test/16287
# /kaggle/input/reuters/reuters/test/21502
# /kaggle/input/reuters/reuters/test/18782
# /kaggle/input/reuters/reuters/test/20058
# /kaggle/input/reuters/reuters/test/19088
# /kaggle/input/reuters/reuters/test/15124
# /kaggle/input/reuters/reuters/test/19697
# /kaggle/input/reuters/reuters/test/19497
# /kaggle/input/reuters/reuters/test/20031
# /kaggle/input/reuters/reuters/test/21300
# /kaggle/input/reuters/reuters/test/20907
# /kaggle/input/reuters/reuters/test/14978
# /kaggle/input/reuters/reuters/test/15106
# /kaggle/input/reuters/reuters/test/21055
# /kaggle/input/reuters/reuters/test/18495
# /kaggle/input/reuters/reuters/test/20080
# /kaggle/input/reuters/reuters/test/14863
# /kaggle/input/reuters/reuters/test/18079
# /kaggle/input/reuters/reuters/test/20628
# /kaggle/input/reuters/reuters/test/20249
# /kaggle/input/reuters/reuters/test/17048
# /kaggle/input/reuters/reuters/test/21275
# /kaggle/input/reuters/reuters/test/15226
# /kaggle/input/reuters/reuters/test/14958
# /kaggle/input/reuters/reuters/test/15639
# /kaggle/input/reuters/reuters/test/21034
# /kaggle/input/reuters/reuters/test/20958
# /kaggle/input/reuters/reuters/test/17752
# /kaggle/input/reuters/reuters/test/20814
# /kaggle/input/reuters/reuters/test/15441
# /kaggle/input/reuters/reuters/test/16030
# /kaggle/input/reuters/reuters/test/21496
# /kaggle/input/reuters/reuters/test/21541
# /kaggle/input/reuters/reuters/test/19121
# /kaggle/input/reuters/reuters/test/18366
# /kaggle/input/reuters/reuters/test/16908
# /kaggle/input/reuters/reuters/test/17455
# /kaggle/input/reuters/reuters/test/20165
# /kaggle/input/reuters/reuters/test/18166
# /kaggle/input/reuters/reuters/test/17707
# /kaggle/input/reuters/reuters/test/20728
# /kaggle/input/reuters/reuters/test/21124
# /kaggle/input/reuters/reuters/test/17802
# /kaggle/input/reuters/reuters/test/17457
# /kaggle/input/reuters/reuters/test/21255
# /kaggle/input/reuters/reuters/test/19966
# /kaggle/input/reuters/reuters/test/17798
# /kaggle/input/reuters/reuters/test/16377
# /kaggle/input/reuters/reuters/test/15762
# /kaggle/input/reuters/reuters/test/16096
# /kaggle/input/reuters/reuters/test/20256
# /kaggle/input/reuters/reuters/test/20984
# /kaggle/input/reuters/reuters/test/18534
# /kaggle/input/reuters/reuters/test/19702
# /kaggle/input/reuters/reuters/test/15351
# /kaggle/input/reuters/reuters/test/20493
# /kaggle/input/reuters/reuters/test/16252
# /kaggle/input/reuters/reuters/test/16193
# /kaggle/input/reuters/reuters/test/21372
# /kaggle/input/reuters/reuters/test/20693
# /kaggle/input/reuters/reuters/test/18155
# /kaggle/input/reuters/reuters/test/15204
# /kaggle/input/reuters/reuters/test/15572
# /kaggle/input/reuters/reuters/test/20807
# /kaggle/input/reuters/reuters/test/16401
# /kaggle/input/reuters/reuters/test/20001
# /kaggle/input/reuters/reuters/test/15676
# /kaggle/input/reuters/reuters/test/16563
# /kaggle/input/reuters/reuters/test/18062
# /kaggle/input/reuters/reuters/test/21063
# /kaggle/input/reuters/reuters/test/20191
# /kaggle/input/reuters/reuters/test/18276
# /kaggle/input/reuters/reuters/test/20419
# /kaggle/input/reuters/reuters/test/21405
# /kaggle/input/reuters/reuters/test/18994
# /kaggle/input/reuters/reuters/test/21333
# /kaggle/input/reuters/reuters/test/16392
# /kaggle/input/reuters/reuters/test/18664
# /kaggle/input/reuters/reuters/test/17446
# /kaggle/input/reuters/reuters/test/20105
# /kaggle/input/reuters/reuters/test/21173
# /kaggle/input/reuters/reuters/test/19828
# /kaggle/input/reuters/reuters/test/17659
# /kaggle/input/reuters/reuters/test/21131
# /kaggle/input/reuters/reuters/test/17785
# /kaggle/input/reuters/reuters/test/19991
# /kaggle/input/reuters/reuters/test/17894
# /kaggle/input/reuters/reuters/test/14829
# /kaggle/input/reuters/reuters/test/20195
# /kaggle/input/reuters/reuters/test/15811
# /kaggle/input/reuters/reuters/test/21485
# /kaggle/input/reuters/reuters/test/18743
# /kaggle/input/reuters/reuters/test/19764
# /kaggle/input/reuters/reuters/test/15274
# /kaggle/input/reuters/reuters/test/16644
# /kaggle/input/reuters/reuters/test/18217
# /kaggle/input/reuters/reuters/test/21045
# /kaggle/input/reuters/reuters/test/15109
# /kaggle/input/reuters/reuters/test/16658
# /kaggle/input/reuters/reuters/test/17493
# /kaggle/input/reuters/reuters/test/20252
# /kaggle/input/reuters/reuters/test/19294
# /kaggle/input/reuters/reuters/test/19029
# /kaggle/input/reuters/reuters/test/17685
# /kaggle/input/reuters/reuters/test/19555
# /kaggle/input/reuters/reuters/test/19731
# /kaggle/input/reuters/reuters/test/16802
# /kaggle/input/reuters/reuters/test/15001
# /kaggle/input/reuters/reuters/test/19473
# /kaggle/input/reuters/reuters/test/16676
# /kaggle/input/reuters/reuters/test/17975
# /kaggle/input/reuters/reuters/test/20517
# /kaggle/input/reuters/reuters/test/19912
# /kaggle/input/reuters/reuters/test/14957
# /kaggle/input/reuters/reuters/test/16583
# /kaggle/input/reuters/reuters/test/21178
# /kaggle/input/reuters/reuters/test/16434
# /kaggle/input/reuters/reuters/test/16597
# /kaggle/input/reuters/reuters/test/16300
# /kaggle/input/reuters/reuters/test/19416
# /kaggle/input/reuters/reuters/test/17742
# /kaggle/input/reuters/reuters/test/16383
# /kaggle/input/reuters/reuters/test/15636
# /kaggle/input/reuters/reuters/test/16663
# /kaggle/input/reuters/reuters/test/20215
# /kaggle/input/reuters/reuters/test/19786
# /kaggle/input/reuters/reuters/test/18698
# /kaggle/input/reuters/reuters/test/15886
# /kaggle/input/reuters/reuters/test/21441
# /kaggle/input/reuters/reuters/test/16311
# /kaggle/input/reuters/reuters/test/14960
# /kaggle/input/reuters/reuters/test/19760
# /kaggle/input/reuters/reuters/test/15559

# %% [markdown]
# Carga del corpus de Reuters utilizando un cargador diferido y especificación de cómo deben ser categorizados los archivos, así como la codificación y la ubicación de los datos.

# %%
# Configuración del directorio del corpus de Reuters
corpus_root = '/kaggle/input/reuters/reuters'

# %%
# Enumerando el id y las categorías de los primeros 5 documentos
# !head -n 5 '/kaggle/input/reuters/reuters/cats.txt'
# Out:
# test/14826 trade
# test/14828 grain
# test/14829 nat-gas crude
# test/14832 rubber tin sugar corn rice grain trade
# test/14833 palm-oil veg-oil

# %%
# Cargar el corpus de Reuters
reuters = CategorizedPlaintextCorpusReader(
    corpus_root,
    r'(training|test).*',
    cat_file='cats.txt',
    encoding='ISO-8859-2'
)

# %%
reuters.words() #acceso a todas las palabras del corpus
# Out:
# ['ASIAN', 'EXPORTERS', 'FEAR', 'DAMAGE', 'FROM', 'U', ...]

# %% [markdown]
# Conteo y mostrar el número de categorías en el corpus de Reuters, y luego listar todas las categorías disponibles en el corpus.

# %%
num_of_cat = len(reuters.categories())
print('Numero de categorias: ' + str(num_of_cat) + ' categories')
reuters.categories() #lista de todas las categorías en el corpus.
# Out:
# Numero de categorias: 90 categories
# ['acq',
#  'alum',
#  'barley',
#  'bop',
#  'carcass',
#  'castor-oil',
#  'cocoa',
#  'coconut',
#  'coconut-oil',
#  'coffee',
#  'copper',
#  'copra-cake',
#  'corn',
#  'cotton',
#  'cotton-oil',
#  'cpi',
#  'cpu',
#  'crude',
#  'dfl',
#  'dlr',
#  'dmk',
#  'earn',
#  'fuel',
#  'gas',
#  'gnp',
#  'gold',
#  'grain',
#  'groundnut',
#  'groundnut-oil',
#  'heat',
#  'hog',
#  'housing',
#  'income',
#  'instal-debt',
#  'interest',
#  'ipi',
#  'iron-steel',
#  'jet',
#  'jobs',
#  'l-cattle',
#  'lead',
#  'lei',
#  'lin-oil',
#  'livestock',
#  'lumber',
#  'meal-feed',
#  'money-fx',
#  'money-supply',
#  'naphtha',
#  'nat-gas',
#  'nickel',
#  'nkr',
#  'nzdlr',
#  'oat',
#  'oilseed',
#  'orange',
#  'palladium',
#  'palm-oil',
#  'palmkernel',
#  'pet-chem',
#  'platinum',
#  'potato',
#  'propane',
#  'rand',
#  'rape-oil',
#  'rapeseed',
#  'reserves',
#  'retail',
#  'rice',
#  'rubber',
#  'rye',
#  'ship',
#  'silver',
#  'sorghum',
#  'soy-meal',
#  'soy-oil',
#  'soybean',
#  'strategic-metal',
#  'sugar',
#  'sun-meal',
#  'sun-oil',
#  'sunseed',
#  'tea',
#  'tin',
#  'trade',
#  'veg-oil',
#  'wheat',
#  'wpi',
#  'yen',
#  'zinc']

# %% [markdown]
# Recorremos los primeros cinco artículos en la categoría "trade" del corpus de Reuters. Para cada artículo, imprimimos el número del artículo (de 1 a 5). Ademas, imprimimos el contenido completo (texto sin procesar) del artículo correspondiente.

# %%
for i in range(5):
    print('Article #' + str(i+1))
    print(reuters.raw(reuters.fileids("trade")[i]))
# Out:
# Article #1
# ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT
#   Mounting trade friction between the
#   U.S. And Japan has raised fears among many of Asia's exporting
#   nations that the row could inflict far-reaching economic
#   damage, businessmen and officials said.
#       They told Reuter correspondents in Asian capitals a U.S.
#   Move against Japan might boost protectionist sentiment in the
#   U.S. And lead to curbs on American imports of their products.
#       But some exporters said that while the conflict would hurt
#   them in the long-run, in the short-term Tokyo's loss might be
#   their gain.
#       The U.S. Has said it will impose 300 mln dlrs of tariffs on
#   imports of Japanese electronics goods on April 17, in
#   retaliation for Japan's alleged failure to stick to a pact not
#   to sell semiconductors on world markets at below cost.
#       Unofficial Japanese estimates put the impact of the tariffs
#   at 10 billion dlrs and spokesmen for major electronics firms
#   said they would virtually halt exports of products hit by the
#   new taxes.
#       "We wouldn't be able to do business," said a spokesman for
#   leading Japanese electronics firm Matsushita Electric
#   Industrial Co Ltd &lt;MC.T>.
#       "If the tariffs remain in place for any length of time
#   beyond a few months it will mean the complete erosion of
#   exports (of goods subject to tariffs) to the U.S.," said Tom
#   Murtha, a stock analyst at the Tokyo office of broker &lt;James
#   Capel and Co>.
#       In Taiwan, businessmen and officials are also worried.
#       "We are aware of the seriousness of the U.S. Threat against
#   Japan because it serves as a warning to us," said a senior
#   Taiwanese trade official who asked not to be named.
#       Taiwan had a trade trade surplus of 15.6 billion dlrs last
#   year, 95 pct of it with the U.S.
#       The surplus helped swell Taiwan's foreign exchange reserves
#   to 53 billion dlrs, among the world's largest.
#       "We must quickly open our markets, remove trade barriers and
#   cut import tariffs to allow imports of U.S. Products, if we
#   want to defuse problems from possible U.S. Retaliation," said
#   Paul Sheen, chairman of textile exporters &lt;Taiwan Safe Group>.
#       A senior official of South Korea's trade promotion
#   association said the trade dispute between the U.S. And Japan
#   might also lead to pressure on South Korea, whose chief exports
#   are similar to those of Japan.
#       Last year South Korea had a trade surplus of 7.1 billion
#   dlrs with the U.S., Up from 4.9 billion dlrs in 1985.
#       In Malaysia, trade officers and businessmen said tough
#   curbs against Japan might allow hard-hit producers of
#   semiconductors in third countries to expand their sales to the
#   U.S.
#       In Hong Kong, where newspapers have alleged Japan has been
#   selling below-cost semiconductors, some electronics
#   manufacturers share that view. But other businessmen said such
#   a short-term commercial advantage would be outweighed by
#   further U.S. Pressure to block imports.
#       "That is a very short-term view," said Lawrence Mills,
#   director-general of the Federation of Hong Kong Industry.
#       "If the whole purpose is to prevent imports, one day it will
#   be extended to other sources. Much more serious for Hong Kong
#   is the disadvantage of action restraining trade," he said.
#       The U.S. Last year was Hong Kong's biggest export market,
#   accounting for over 30 pct of domestically produced exports.
#       The Australian government is awaiting the outcome of trade
#   talks between the U.S. And Japan with interest and concern,
#   Industry Minister John Button said in Canberra last Friday.
#       "This kind of deterioration in trade relations between two
#   countries which are major trading partners of ours is a very
#   serious matter," Button said.
#       He said Australia's concerns centred on coal and beef,
#   Australia's two largest exports to Japan and also significant
#   U.S. Exports to that country.
#       Meanwhile U.S.-Japanese diplomatic manoeuvres to solve the
#   trade stand-off continue.
#       Japan's ruling Liberal Democratic Party yesterday outlined
#   a package of economic measures to boost the Japanese economy.
#       The measures proposed include a large supplementary budget
#   and record public works spending in the first half of the
#   financial year.
#       They also call for stepped-up spending as an emergency
#   measure to stimulate the economy despite Prime Minister
#   Yasuhiro Nakasone's avowed fiscal reform program.
#       Deputy U.S. Trade Representative Michael Smith and Makoto
#   Kuroda, Japan's deputy minister of International Trade and
#   Industry (MITI), are due to meet in Washington this week in an
#   effort to end the dispute.
#
#
#
# Article #2
# THAI TRADE DEFICIT WIDENS IN FIRST QUARTER
#   Thailand's trade deficit widened to 4.5
#   billion baht in the first quarter of 1987 from 2.1 billion a
#   year ago, the Business Economics Department said.
#       It said Janunary/March imports rose to 65.1 billion baht
#   from 58.7 billion. Thailand's improved business climate this
#   year resulted in a 27 pct increase in imports of raw materials
#   and semi-finished products.
#       The country's oil import bill, however, fell 23 pct in the
#   first quarter due to lower oil prices.
#       The department said first quarter exports expanded to 60.6
#   billion baht from 56.6 billion.
#       Export growth was smaller than expected due to lower
#   earnings from many key commodities including rice whose
#   earnings declined 18 pct, maize 66 pct, sugar 45 pct, tin 26
#   pct and canned pineapples seven pct.
#       Products registering high export growth were jewellery up
#   64 pct, clothing 57 pct and rubber 35 pct.
#
#
#
# Article #3
# JAPAN MINISTRY SAYS OPEN FARM TRADE WOULD HIT U.S.
#   Japan's Agriculture Ministry, angered by
#   U.S. Demands that Japan open its farm products market, will
#   tell U.S. Officials at talks later this month that
#   liberalisation would harm existing U.S. Farm exports to Japan,
#   a senior ministry official said.
#       "Imports from the U.S. Would drop due to active sales drives
#   by other suppliers," the official, who declined to be named,
#   said. "Japan is the largest customer for U.S. Farm products and
#   it is not reasonable for the U.S. To demand Japan liberalise
#   its farm import market," he said.
#       Agriculture Minister Mutsuki Kato has said if the U.S.
#   Insists Japan open its protected rice market it will also open
#   its wheat market, where volume and origin are regulated to
#   protect local farmers.
#       Australia and Canada could then increase their wheat
#   exports as they are more competitive than the U.S., He said.
#   End-users would also buy other origins, grain traders said.
#       U.S. Agriculture Secretary Richard Lyng, who is due to
#   visit Japan for talks between April 16-27, has said he will ask
#   Japan to offer a share of its rice market to U.S. Suppliers and
#   remove quotas on U.S. Beef and citrus imports.
#       Other countries are already cutting into the U.S. Market
#   share here. Australia, the largest beef supplier to Japan, has
#   been trying to boost exports prior to the expiry of a four-year
#   beef accord next March 31.
#       Imports of U.S. Corn have fallen due to increased sales
#   from China and South America, while Japanese soybean imports
#   from Brazil are expected to rise sharply this year, although
#   the U.S. Will remain the largest supplier.
#       U.S. Feedgrain sales will also drop if Japan opens up its
#   beef imports, since Japan depends almost entirely on feedgrain
#   imports, mainly from the U.S., Japanese officials said.
#       An indication of the U.S. Position came last December when
#   Under Secretary of Agriculture Daniel Amstutz said Japan has
#   the potential to provide one of the largest boosts to U.S.
#   Agricultural exports, with the beef market alone representing
#   some one billion dlrs in new business.
#       The U.S. Has also asked the General Agreement on Tariffs
#   and Trade to investigate the legality of Japanese import
#   controls on 12 other farm products, including fruit juices,
#   purees and pulp, tomato juice, ketchup and sauce, peanuts,
#   prepared beef products and miscellaneous beans.
#       To help calm heated trade relations with the U.S., Japan's
#   top business group Keidanren has urged the government to remove
#   residual import restrictions on agricultural products.
#       But Agriculture Minister Kato has ruled out any emotional
#   reaction, and the senior ministry official said the farm issue
#   should not become a scapegoat for trade pressure in the
#   industrial sector.
#       "Japan is the largest buyer of U.S. Farm products, and these
#   issues should not be discussed on the same table," the official
#   said.
#
#
#
# Article #4
# SOUTH KOREA MOVES TO SLOW GROWTH OF TRADE SURPLUS
#   South Korea's trade surplus is growing too
#   fast and the government has started taking steps to slow it
#   down, Deputy Prime Minister Kim Mahn-je said.
#       He told a press conference the government planned to
#   increase investment, speed up the opening of the local market
#   to foreign imports and gradually adjust its currency to hold
#   the surplus "at a proper level."
#       But he said the government would not allow the won to
#   appreciate too much in a short period of time. South Korea has
#   been under pressure from Washington to revalue the won.
#       The U.S. Wants South Korea to cut its trade surplus with
#   the U.S., Which rose to 7.4 billion dlrs in 1986 from 4.3
#   billion dlrs in 1985.
#       Kim, who is also economic planning minister, said prospects
#   were bright for the South Korean economy, but the government
#   would try to hold the current account surplus to around five
#   billion dlrs a year for the next five years.
#       "Our government projections of eight pct GNP growth, five
#   billion dlrs of (current account) surplus and 12 pct growth in
#   exports all seemed to be reasonable early this year. But now
#   the surplus is growing faster than we expected," he said.
#       Trade ministry officials said South Korea's exports rose 35
#   pct to 9.34 billion dlrs in the first three months of this
#   year, while imports rose only 8.5 pct to 8.2 billion dlrs.
#       Kim said the swing of South Korea's current account to a
#   surplus of 4.65 billion dlrs in 1986 from an 890 mln dlr
#   deficit in 1985 was very significant. The surplus enabled the
#   country to reduce its foreign debt last year for the first
#   time.
#       South Korea's foreign debt, which fell to 44.5 billion dlrs
#   in 1986 from 46.8 billion in 1985, is still among the largest
#   in Asia.
#       "This huge amount of our foreign debt has been one of the
#   major constraints on our development... Last year was a major
#   turning point for the Korean economy," Kim said.
#       Kim said his government plannned to reduce the ratio of
#   foreign debt to the country's GNP to about 20 pct in 1991, from
#   about 50 pct in 1986.
#       "The government, however, does not want to accelerate
#   reducing the debt by making an excessive trade surplus," he
#   said.
#       Kim said a sudden rise in the surplus would cause inflation
#   and lead to trade friction with Seoul's major trading partners,
#   particularly the United States.
#       "We need a surplus because we have to reduce our debt, but
#   we are taking measures to hold the size of the surplus at a
#   proper level," Kim said.
#
#
#
# Article #5
# JAPAN GIVEN LITTLE HOPE OF AVOIDING U.S. SANCTIONS
#   A top U.S. Official said Japan has little
#   chance of convincing the U.S. To drop threatened trade
#   sanctions, despite the efforts of a Japanese team that left for
#   Washington today.
#       Michael Armacost, Under Secretary of State for Political
#   Affairs, was asked at a press conference whether Japan's moves
#   to boost its domestic economy and open its markets could
#   persuade the U.S. Not to impose tariffs on Japanese imports
#   said, and replied: "...It is probably too early for the figures
#   to demonstrate that the situation has turned around and to
#   permit the result you have described."
#       Armacost said the U.S. Hopes Japan will take steps to lift
#   its domestic economy and reduce dependence on exports, remove
#   barriers to imports and settle outstanding trade issues.
#       "There are obvious problems at the moment in the trade area,
#   but we do not wish those problems to divert attention from
#   important areas of cooperation that continue to exist on
#   security and political issues," he said.
#       "The question is whether through cooperative actions between
#   our governments we can reduce the (trade) imbalance or whether
#   Congress takes action to reduce it through protectionist
#   legislation," he said.

# %% [markdown]
# # 2. Preprocesado

# %% [markdown]
# Se cargan el archivo de stopwords

# %%
# funcion que permite la carga de stopwords
def load_stopwords(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        stopwords = file.read().splitlines()
    return stopwords

# %%
# Cargar stopwords
STOPWORDS = load_stopwords('/kaggle/input/reuters/reuters/stopwords')

# %% [markdown]
# Se procesa los documentos.

# %%
codelist = ['\r', '\n', '\t']  # espacios, saltos de linea a eliminar de los docs

# funcion de analisis de texto para toda la cadena del documento
def parse_doc(text):
    text = text.lower()
    text = re.sub(r'&(.)+', "", text)  # elimina referencias con & 
    text = re.sub(r'pct', 'percent', text)  # reemplaza pct con "percent"  
    text = re.sub(r"[^\w\d'\s]+", '', text)  # elimina toda puntuación excepto el apostrofo 
    text = re.sub(r'[^\x00-\x7f]',r'', text)  # elimina caracteres no ASCII    
    if text.isdigit(): text = ""  # elimina palabras que son solo digitos 
    for code in codelist:
        text = re.sub(code, ' ', text)  # elimina caracteres de escape  
    text = re.sub('\s+', ' ', text)  # reemplaza multiples espacios con uno solo      
    return text

# %% [markdown]
# Se utiliza un conjunto de herramientas para limpiar y preprocesar las palabras del documento, con opciones para eliminar stopwords y realizar stemming.

# %%
DROP_STOPWORDS = True  #eliminacion de stopwords
STEMMING = False  #reduccion de las palabras a su raiz, definido en false para mantener los docs mas legibles 

# funcion que toma una cadena de texto y realiza un procesamiento adicional a nivel de palabras
def parse_words(text): 
    # divide el texto en palabras individuales
    tokens=text.split()
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # elimina la puntuación de cada palabra
    tokens = [re_punc.sub('', w) for w in tokens]
    # filtra las palabras que no son alfabeticas
    tokens = [word for word in tokens if word.isalpha()]
    # filtra las palabras que tienen menos de tres caracteres
    tokens = [word for word in tokens if len(word) > 2]
    # filtra las palabras que tienen más de veinte caracteres
    tokens = [word for word in tokens if len(word) < 21]
    # elimina las stopwords si DROP_STOPWORDS es True
    if DROP_STOPWORDS:
        tokens = [w for w in tokens if not w in STOPWORDS]         
    # realiza stemming si STEMMING es True.
    if STEMMING:
        ps = PorterStemmer()
        tokens = [ps.stem(word) for word in tokens]
       # reconstruye el texto a partir de las palabras procesadas
    text = ''
    for token in tokens:
        text = text + ' ' + token
    return text  # retorna el texto procesado como una cadena

# %% [markdown]
# se utiliza un generador bajo demanda

# %%
# Generador para procesar textos
def generate_processed_texts(docs):
    for doc in docs:
        text_string = parse_doc(doc)
        text_string = parse_words(text_string)
        yield text_string

# %% [markdown]
# Dividimos los documentos del corpus de Reuters en conjuntos de entrenamiento (train_documents) y prueba (test_documents) basándonos en los IDs de archivo que comienzan con "trainning/" y "test/".

# %%
# Procesamiento de textos de entrenamiento y prueba
train_documents = [reuters.raw(fileid) for fileid in reuters.fileids() if fileid.startswith('training/')]
test_documents = [reuters.raw(fileid) for fileid in reuters.fileids() if fileid.startswith('test/')]

# %% [markdown]
# Imprimimos información sobre los documentos de entrenamiento del corpus.

# %%
print(f"Hay {len(train_documents)} noticias de Reuters.")
# Out:
# Hay 7769 noticias de Reuters.

# %% [markdown]
# uso del generador

# %%
# Procesamiento de textos de entrenamiento y prueba usando el generador
train_texts_generator = generate_processed_texts(train_documents)
test_texts_generator = generate_processed_texts(test_documents)

# %% [markdown]
# # 3. Representación de Datos en Espacio Vectorial

# %% [markdown]
# ### BoW

# %%
# BOW
BOW_vectorizer = CountVectorizer()
train_vectors_bow = BOW_vectorizer.fit_transform(train_texts_generator)

# %% [markdown]
# ### TF-IDF

# %%
# Reiniciar el generador para TF-IDF
train_texts_generator = generate_processed_texts(train_documents)

# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer()
train_vectors_tfidf = tfidf_vectorizer.fit_transform(train_texts_generator)

# %% [markdown]
# # 4. Indexación

# %% [markdown]
# Se construye índices invertidos para dos tipos de representaciones vectoriales de documentos: Bolsa de palabras (BOW) y TF-IDF

# %%
# Índice invertido BOW
indice_invertido_bow = defaultdict(list)
vocabulario_bow = BOW_vectorizer.get_feature_names_out()

for i, documento in enumerate(train_documents):
    palabras_indices = train_vectors_bow[i].nonzero()[1]
    for indice_palabra in palabras_indices:
        palabra = vocabulario_bow[indice_palabra]
        indice_invertido_bow[palabra].append(i)

# %%
# Índice invertido TF-IDF
vocabulario_tfidf = tfidf_vectorizer.get_feature_names_out()
indice_invertido_tfidf = defaultdict(list)

for i, documento in enumerate(train_documents):
    palabras_indices = train_vectors_tfidf[i].nonzero()[1]
    for indice_palabra in palabras_indices:
        palabra = vocabulario_tfidf[indice_palabra]
        indice_invertido_tfidf[palabra].append(i)

# %% [markdown]
# # 5. Diseño del Motor de Búsqueda

# %% [markdown]
# Implementacion de la Similitud Coseno, útil para procesar consultas de búsqueda y encontrar documentos relevantes en un conjunto de datos utilizando técnicas de recuperación de información como TF-IDF o bolsa de palabras (BOW).

# %%
# Procesamiento de consulta y ranking de documentos
def procesar_consulta(consulta, vectorizador, indice_invertido, train_vectors):
    consulta_procesada=parse_words(parse_doc(consulta))
    # consulta_procesada=consulta
    consulta_vectorizada = vectorizador.transform([consulta_procesada])
    consulta_indices = consulta_vectorizada.nonzero()[1]
    consulta_terminos = [vectorizador.get_feature_names_out()[i] for i in consulta_indices]

    documentos_relevantes = set()
    for termino in consulta_terminos:
        if termino in indice_invertido:
            documentos_relevantes.update(indice_invertido[termino])

    documentos_relevantes = list(documentos_relevantes)
    if not documentos_relevantes:
        return []

    relevantes = train_vectors[documentos_relevantes]
    similitudes = cosine_similarity(consulta_vectorizada, relevantes).flatten()

    return [(doc, similitud) for doc, similitud in zip(documentos_relevantes, similitudes)]

# %% [markdown]
# Se define una funcion que permite realizar el rankeo de los documentos, se obtiene los documentos más relevantes para una consulta, ordenados por su relevancia medida por la similitud de coseno.

# %%
def rankear_documentos(documentos_similitudes, nombres_archivos, top_n=5):
    documentos_similitudes.sort(key=lambda x: x[1], reverse=True)
    documentos_rankeados = [(nombres_archivos[doc], similitud) for doc, similitud in documentos_similitudes[:top_n]]
    return documentos_rankeados

# %%
# Obtener nombres de documentos de entrenamiento y prueba
train_docs = [os.path.basename(fileid) for fileid in reuters.fileids() if fileid.startswith('training/')]
test_docs = [os.path.basename(fileid) for fileid in reuters.fileids() if fileid.startswith('test/')]

# %% [markdown]
# Consultas y resultados

# %%
# Ejemplo de consulta del usuario
consulta_usuario = "Economic growth in Asia"

documentos_similitudes_tfidf = procesar_consulta(consulta_usuario, tfidf_vectorizer, indice_invertido_tfidf, train_vectors_tfidf)
documentos_rankeados_tfidf = rankear_documentos(documentos_similitudes_tfidf, train_docs)
documentos_similitudes_BOW = procesar_consulta(consulta_usuario, BOW_vectorizer, indice_invertido_bow, train_vectors_bow)
documentos_rankeados_BOW = rankear_documentos(documentos_similitudes_BOW, train_docs)


# print the ranked documents
print("Resultados con TF-IDF:")
for nombre_archivo, similitud in documentos_rankeados_tfidf:
    print(f"Similitud: {similitud:.4f} -> Archivo: {nombre_archivo}")
print("\n")
print("Resultados con Bag of Words:")
for nombre_archivo, similitud in documentos_rankeados_BOW:
    print(f"Similitud: {similitud:.4f} -> Archivo: {nombre_archivo}")
# Out:
# Resultados con TF-IDF:
# Similitud: 0.2707 -> Archivo: 3246
# Similitud: 0.2440 -> Archivo: 237
# Similitud: 0.2437 -> Archivo: 8453
# Similitud: 0.2278 -> Archivo: 11546
# Similitud: 0.2209 -> Archivo: 227
#
#
# Resultados con Bag of Words:
# Similitud: 0.4583 -> Archivo: 3246
# Similitud: 0.3997 -> Archivo: 8453
# Similitud: 0.3608 -> Archivo: 11546
# Similitud: 0.3484 -> Archivo: 227
# Similitud: 0.3450 -> Archivo: 3838

# %% [markdown]
# # 6. Evaluación del Sistema

# %% [markdown]
# obtencion de querys de evaluacion

# %%
# Crear diccionario para almacenar las categorías reales y sus documentos solo para el conjunto de entrenamiento
categorias_reales = {}

# Recorrer todas las categorías en el corpus de Reuters
for categoria in reuters.categories():
    # Filtrar y extraer el número de documento de entrenamiento para la categoría actual
    categorias_reales[categoria]= set(int(fileid.split('/')[1]) for fileid in reuters.fileids(categoria) if fileid.startswith('training/'))

# %% [markdown]
# Función para evaluar el modelo

# %%
def evaluar_modelo(categorias_reales, vectorizer, indice_invertido, train_vectors, train_docs):

    test_search = {}
    
    for categoria in categorias_reales:
        consulta_usuario = procesar_consulta(categoria, vectorizer, indice_invertido, train_vectors)
        if categoria not in test_search:
            test_search[categoria] = set()
        for resultado in consulta_usuario:
            test_search[categoria].add(int(train_docs[resultado[0]]))

    return test_search

# %% [markdown]
# obtencion de resultados para bow y tf-idf

# %%
# BoW
bow_test_search = evaluar_modelo(categorias_reales, BOW_vectorizer, indice_invertido_bow, train_vectors_bow, train_docs)

#TF-IDF
tfidf_test_search = evaluar_modelo(categorias_reales, tfidf_vectorizer, indice_invertido_tfidf, train_vectors_tfidf, train_docs)

# %% [markdown]
# funcion para el calculo de las metricas: precisión, recall y f1

# %%
def calcular_metricas(categorias_diccionario, test_seach):

    metrics_by_category = defaultdict(dict)
    total_precision = 0
    total_recall = 0
    total_f1 = 0

    # Calcular métricas por categoría
    for categoria in categorias_diccionario:
        if categoria in test_seach:
            documentos_recuperados = test_seach[categoria]
            documentos_reales = categorias_diccionario[categoria]

            # Verdaderos Positivos (TP): Documentos recuperados que son relevantes
            tp = len(documentos_recuperados.intersection(documentos_reales))
            
            # Falsos Positivos (FP): Documentos recuperados que no son relevantes
            fp = len(documentos_recuperados - documentos_reales)
            
            # Falsos Negativos (FN): Documentos relevantes que no fueron recuperados
            fn = len(documentos_reales - documentos_recuperados)
            
            # Precisión: TP / (TP + FP)
            precision = tp / (tp + fp) if (tp + fp) > 0 else 0
            
            # Recall: TP / (TP + FN)
            recall = tp / (tp + fn) if (tp + fn) > 0 else 0
            
            # F1-score: 2 * (Precisión * Recall) / (Precisión + Recall)
            f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
            
            # Guardar métricas por categoría
            metrics_by_category[categoria]['TP'] = tp
            metrics_by_category[categoria]['FP'] = fp
            metrics_by_category[categoria]['FN'] = fn
            metrics_by_category[categoria]['Precision'] = precision
            metrics_by_category[categoria]['Recall'] = recall
            metrics_by_category[categoria]['F1-score'] = f1_score
            
            # las métricas globales
            total_precision += precision
            total_recall += recall
            total_f1 += f1_score

    # Calcular métricas globales
    precision_global = total_precision / len(categorias_diccionario)
    recall_global = total_recall / len(categorias_diccionario)
    f1_score_global = total_f1 / len(categorias_diccionario)
    
    return metrics_by_category, precision_global, recall_global, f1_score_global

# %% [markdown]
# Obtencion de las metricas para bow y tf-idf

# %%
# Llamada a la función para calcular métricas

#BOW
metrics_by_category_bow, precision_global_bow, recall_global_bow, f1_score_global_bow = calcular_metricas(categorias_reales,bow_test_search)

#TF-IDF
metrics_by_category_tfidf, precision_global_tfidf, recall_global_tfidf, f1_score_global_tfidf = calcular_metricas(categorias_reales, tfidf_test_search)

# %% [markdown]
# Funciones para mostrar resultados

# %%
def imprimir_metricas_por_categoria(metrics_by_category):
    for categoria, metrics in metrics_by_category.items():
        print(f"Categoría: {categoria}")
        print(f"   TP: {metrics['TP']}")
        print(f"   FP: {metrics['FP']}")
        print(f"   FN: {metrics['FN']}")
        print(f"   Precisión: {metrics['Precision']:.4f}")
        print(f"   Recall: {metrics['Recall']:.4f}")
        print(f"   F1-score: {metrics['F1-score']:.4f}")
        print()

# %%
def imprimir_metricas_globales(precision_global, recall_global, f1_score_global):
    print("Métricas globales:")
    print(f"   Precisión Global: {precision_global:.4f}")
    print(f"   Recall Global: {recall_global:.4f}")
    print(f"   F1-score Global: {f1_score_global:.4f}")
    print()

# %% [markdown]
# Metricas Obtenidas de BoW y TF-IDF

# %%
# Imprimir métricas por categoría y globales para BoW
print("Métricas BoW:")
imprimir_metricas_por_categoria(metrics_by_category_bow)
imprimir_metricas_globales(precision_global_bow, recall_global_bow, f1_score_global_bow)
# Out:
# Métricas BoW:
# Categoría: acq
#    TP: 0
#    FP: 0
#    FN: 1650
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: alum
#    TP: 0
#    FP: 0
#    FN: 35
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: barley
#    TP: 37
#    FP: 15
#    FN: 0
#    Precisión: 0.7115
#    Recall: 1.0000
#    F1-score: 0.8315
#
# Categoría: bop
#    TP: 0
#    FP: 0
#    FN: 75
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: carcass
#    TP: 3
#    FP: 0
#    FN: 47
#    Precisión: 1.0000
#    Recall: 0.0600
#    F1-score: 0.1132
#
# Categoría: castor-oil
#    TP: 0
#    FP: 0
#    FN: 1
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: cocoa
#    TP: 53
#    FP: 6
#    FN: 2
#    Precisión: 0.8983
#    Recall: 0.9636
#    F1-score: 0.9298
#
# Categoría: coconut
#    TP: 4
#    FP: 11
#    FN: 0
#    Precisión: 0.2667
#    Recall: 1.0000
#    F1-score: 0.4211
#
# Categoría: coconut-oil
#    TP: 0
#    FP: 0
#    FN: 4
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: coffee
#    TP: 111
#    FP: 16
#    FN: 0
#    Precisión: 0.8740
#    Recall: 1.0000
#    F1-score: 0.9328
#
# Categoría: copper
#    TP: 45
#    FP: 11
#    FN: 2
#    Precisión: 0.8036
#    Recall: 0.9574
#    F1-score: 0.8738
#
# Categoría: copra-cake
#    TP: 0
#    FP: 0
#    FN: 2
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: corn
#    TP: 132
#    FP: 30
#    FN: 49
#    Precisión: 0.8148
#    Recall: 0.7293
#    F1-score: 0.7697
#
# Categoría: cotton
#    TP: 39
#    FP: 15
#    FN: 0
#    Precisión: 0.7222
#    Recall: 1.0000
#    F1-score: 0.8387
#
# Categoría: cotton-oil
#    TP: 0
#    FP: 0
#    FN: 1
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: cpi
#    TP: 2
#    FP: 3
#    FN: 67
#    Precisión: 0.4000
#    Recall: 0.0290
#    F1-score: 0.0541
#
# Categoría: cpu
#    TP: 0
#    FP: 0
#    FN: 3
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: crude
#    TP: 179
#    FP: 58
#    FN: 210
#    Precisión: 0.7553
#    Recall: 0.4602
#    F1-score: 0.5719
#
# Categoría: dfl
#    TP: 0
#    FP: 0
#    FN: 2
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: dlr
#    TP: 27
#    FP: 655
#    FN: 104
#    Precisión: 0.0396
#    Recall: 0.2061
#    F1-score: 0.0664
#
# Categoría: dmk
#    TP: 0
#    FP: 0
#    FN: 10
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: earn
#    TP: 17
#    FP: 19
#    FN: 2860
#    Precisión: 0.4722
#    Recall: 0.0059
#    F1-score: 0.0117
#
# Categoría: fuel
#    TP: 13
#    FP: 57
#    FN: 0
#    Precisión: 0.1857
#    Recall: 1.0000
#    F1-score: 0.3133
#
# Categoría: gas
#    TP: 7
#    FP: 260
#    FN: 30
#    Precisión: 0.0262
#    Recall: 0.1892
#    F1-score: 0.0461
#
# Categoría: gnp
#    TP: 36
#    FP: 10
#    FN: 65
#    Precisión: 0.7826
#    Recall: 0.3564
#    F1-score: 0.4898
#
# Categoría: gold
#    TP: 94
#    FP: 69
#    FN: 0
#    Precisión: 0.5767
#    Recall: 1.0000
#    F1-score: 0.7315
#
# Categoría: grain
#    TP: 182
#    FP: 28
#    FN: 251
#    Precisión: 0.8667
#    Recall: 0.4203
#    F1-score: 0.5661
#
# Categoría: groundnut
#    TP: 0
#    FP: 3
#    FN: 5
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: groundnut-oil
#    TP: 0
#    FP: 0
#    FN: 1
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: heat
#    TP: 0
#    FP: 11
#    FN: 14
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: hog
#    TP: 9
#    FP: 5
#    FN: 7
#    Precisión: 0.6429
#    Recall: 0.5625
#    F1-score: 0.6000
#
# Categoría: housing
#    TP: 12
#    FP: 24
#    FN: 4
#    Precisión: 0.3333
#    Recall: 0.7500
#    F1-score: 0.4615
#
# Categoría: income
#    TP: 4
#    FP: 296
#    FN: 5
#    Precisión: 0.0133
#    Recall: 0.4444
#    F1-score: 0.0259
#
# Categoría: instal-debt
#    TP: 0
#    FP: 0
#    FN: 5
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: interest
#    TP: 121
#    FP: 483
#    FN: 226
#    Precisión: 0.2003
#    Recall: 0.3487
#    F1-score: 0.2545
#
# Categoría: ipi
#    TP: 0
#    FP: 0
#    FN: 41
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: iron-steel
#    TP: 0
#    FP: 0
#    FN: 40
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: jet
#    TP: 3
#    FP: 3
#    FN: 1
#    Precisión: 0.5000
#    Recall: 0.7500
#    F1-score: 0.6000
#
# Categoría: jobs
#    TP: 8
#    FP: 38
#    FN: 38
#    Precisión: 0.1739
#    Recall: 0.1739
#    F1-score: 0.1739
#
# Categoría: l-cattle
#    TP: 0
#    FP: 0
#    FN: 6
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: lead
#    TP: 14
#    FP: 124
#    FN: 1
#    Precisión: 0.1014
#    Recall: 0.9333
#    F1-score: 0.1830
#
# Categoría: lei
#    TP: 0
#    FP: 0
#    FN: 12
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: lin-oil
#    TP: 1
#    FP: 0
#    FN: 0
#    Precisión: 1.0000
#    Recall: 1.0000
#    F1-score: 1.0000
#
# Categoría: livestock
#    TP: 15
#    FP: 17
#    FN: 60
#    Precisión: 0.4688
#    Recall: 0.2000
#    F1-score: 0.2804
#
# Categoría: lumber
#    TP: 6
#    FP: 12
#    FN: 4
#    Precisión: 0.3333
#    Recall: 0.6000
#    F1-score: 0.4286
#
# Categoría: meal-feed
#    TP: 0
#    FP: 0
#    FN: 30
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: money-fx
#    TP: 0
#    FP: 0
#    FN: 538
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: money-supply
#    TP: 0
#    FP: 0
#    FN: 140
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: naphtha
#    TP: 2
#    FP: 3
#    FN: 0
#    Precisión: 0.4000
#    Recall: 1.0000
#    F1-score: 0.5714
#
# Categoría: nat-gas
#    TP: 0
#    FP: 0
#    FN: 75
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: nickel
#    TP: 7
#    FP: 4
#    FN: 1
#    Precisión: 0.6364
#    Recall: 0.8750
#    F1-score: 0.7368
#
# Categoría: nkr
#    TP: 0
#    FP: 0
#    FN: 1
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: nzdlr
#    TP: 0
#    FP: 0
#    FN: 2
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: oat
#    TP: 1
#    FP: 1
#    FN: 7
#    Precisión: 0.5000
#    Recall: 0.1250
#    F1-score: 0.2000
#
# Categoría: oilseed
#    TP: 15
#    FP: 4
#    FN: 109
#    Precisión: 0.7895
#    Recall: 0.1210
#    F1-score: 0.2098
#
# Categoría: orange
#    TP: 12
#    FP: 5
#    FN: 4
#    Precisión: 0.7059
#    Recall: 0.7500
#    F1-score: 0.7273
#
# Categoría: palladium
#    TP: 2
#    FP: 2
#    FN: 0
#    Precisión: 0.5000
#    Recall: 1.0000
#    F1-score: 0.6667
#
# Categoría: palm-oil
#    TP: 0
#    FP: 0
#    FN: 30
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: palmkernel
#    TP: 0
#    FP: 1
#    FN: 2
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: pet-chem
#    TP: 0
#    FP: 0
#    FN: 20
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: platinum
#    TP: 5
#    FP: 5
#    FN: 0
#    Precisión: 0.5000
#    Recall: 1.0000
#    F1-score: 0.6667
#
# Categoría: potato
#    TP: 3
#    FP: 3
#    FN: 0
#    Precisión: 0.5000
#    Recall: 1.0000
#    F1-score: 0.6667
#
# Categoría: propane
#    TP: 2
#    FP: 3
#    FN: 1
#    Precisión: 0.4000
#    Recall: 0.6667
#    F1-score: 0.5000
#
# Categoría: rand
#    TP: 2
#    FP: 20
#    FN: 0
#    Precisión: 0.0909
#    Recall: 1.0000
#    F1-score: 0.1667
#
# Categoría: rape-oil
#    TP: 0
#    FP: 0
#    FN: 5
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: rapeseed
#    TP: 16
#    FP: 6
#    FN: 2
#    Precisión: 0.7273
#    Recall: 0.8889
#    F1-score: 0.8000
#
# Categoría: reserves
#    TP: 51
#    FP: 227
#    FN: 4
#    Precisión: 0.1835
#    Recall: 0.9273
#    F1-score: 0.3063
#
# Categoría: retail
#    TP: 17
#    FP: 75
#    FN: 6
#    Precisión: 0.1848
#    Recall: 0.7391
#    F1-score: 0.2957
#
# Categoría: rice
#    TP: 34
#    FP: 14
#    FN: 1
#    Precisión: 0.7083
#    Recall: 0.9714
#    F1-score: 0.8193
#
# Categoría: rubber
#    TP: 36
#    FP: 17
#    FN: 1
#    Precisión: 0.6792
#    Recall: 0.9730
#    F1-score: 0.8000
#
# Categoría: rye
#    TP: 1
#    FP: 1
#    FN: 0
#    Precisión: 0.5000
#    Recall: 1.0000
#    F1-score: 0.6667
#
# Categoría: ship
#    TP: 35
#    FP: 21
#    FN: 162
#    Precisión: 0.6250
#    Recall: 0.1777
#    F1-score: 0.2767
#
# Categoría: silver
#    TP: 20
#    FP: 27
#    FN: 1
#    Precisión: 0.4255
#    Recall: 0.9524
#    F1-score: 0.5882
#
# Categoría: sorghum
#    TP: 22
#    FP: 5
#    FN: 2
#    Precisión: 0.8148
#    Recall: 0.9167
#    F1-score: 0.8627
#
# Categoría: soy-meal
#    TP: 8
#    FP: 0
#    FN: 5
#    Precisión: 1.0000
#    Recall: 0.6154
#    F1-score: 0.7619
#
# Categoría: soy-oil
#    TP: 3
#    FP: 4
#    FN: 11
#    Precisión: 0.4286
#    Recall: 0.2143
#    F1-score: 0.2857
#
# Categoría: soybean
#    TP: 58
#    FP: 22
#    FN: 20
#    Precisión: 0.7250
#    Recall: 0.7436
#    F1-score: 0.7342
#
# Categoría: strategic-metal
#    TP: 0
#    FP: 0
#    FN: 16
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: sugar
#    TP: 119
#    FP: 27
#    FN: 7
#    Precisión: 0.8151
#    Recall: 0.9444
#    F1-score: 0.8750
#
# Categoría: sun-meal
#    TP: 0
#    FP: 2
#    FN: 1
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: sun-oil
#    TP: 1
#    FP: 0
#    FN: 4
#    Precisión: 1.0000
#    Recall: 0.2000
#    F1-score: 0.3333
#
# Categoría: sunseed
#    TP: 0
#    FP: 0
#    FN: 11
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: tea
#    TP: 9
#    FP: 12
#    FN: 0
#    Precisión: 0.4286
#    Recall: 1.0000
#    F1-score: 0.6000
#
# Categoría: tin
#    TP: 18
#    FP: 10
#    FN: 0
#    Precisión: 0.6429
#    Recall: 1.0000
#    F1-score: 0.7826
#
# Categoría: trade
#    TP: 343
#    FP: 467
#    FN: 25
#    Precisión: 0.4235
#    Recall: 0.9321
#    F1-score: 0.5823
#
# Categoría: veg-oil
#    TP: 0
#    FP: 0
#    FN: 87
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: wheat
#    TP: 203
#    FP: 38
#    FN: 9
#    Precisión: 0.8423
#    Recall: 0.9575
#    F1-score: 0.8962
#
# Categoría: wpi
#    TP: 0
#    FP: 0
#    FN: 19
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: yen
#    TP: 44
#    FP: 169
#    FN: 1
#    Precisión: 0.2066
#    Recall: 0.9778
#    F1-score: 0.3411
#
# Categoría: zinc
#    TP: 21
#    FP: 6
#    FN: 0
#    Precisión: 0.7778
#    Recall: 1.0000
#    F1-score: 0.8750
#
# Métricas globales:
#    Precisión Global: 0.3458
#    Recall Global: 0.4423
#    F1-score Global: 0.3352

# %%
# Imprimir métricas por categoría y globales para TF-IDF
print("Métricas TF-IDF:")
imprimir_metricas_por_categoria(metrics_by_category_tfidf)
imprimir_metricas_globales(precision_global_tfidf, recall_global_tfidf, f1_score_global_tfidf)
# Out:
# Métricas TF-IDF:
# Categoría: acq
#    TP: 0
#    FP: 0
#    FN: 1650
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: alum
#    TP: 0
#    FP: 0
#    FN: 35
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: barley
#    TP: 37
#    FP: 15
#    FN: 0
#    Precisión: 0.7115
#    Recall: 1.0000
#    F1-score: 0.8315
#
# Categoría: bop
#    TP: 0
#    FP: 0
#    FN: 75
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: carcass
#    TP: 3
#    FP: 0
#    FN: 47
#    Precisión: 1.0000
#    Recall: 0.0600
#    F1-score: 0.1132
#
# Categoría: castor-oil
#    TP: 0
#    FP: 0
#    FN: 1
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: cocoa
#    TP: 53
#    FP: 6
#    FN: 2
#    Precisión: 0.8983
#    Recall: 0.9636
#    F1-score: 0.9298
#
# Categoría: coconut
#    TP: 4
#    FP: 11
#    FN: 0
#    Precisión: 0.2667
#    Recall: 1.0000
#    F1-score: 0.4211
#
# Categoría: coconut-oil
#    TP: 0
#    FP: 0
#    FN: 4
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: coffee
#    TP: 111
#    FP: 16
#    FN: 0
#    Precisión: 0.8740
#    Recall: 1.0000
#    F1-score: 0.9328
#
# Categoría: copper
#    TP: 45
#    FP: 11
#    FN: 2
#    Precisión: 0.8036
#    Recall: 0.9574
#    F1-score: 0.8738
#
# Categoría: copra-cake
#    TP: 0
#    FP: 0
#    FN: 2
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: corn
#    TP: 132
#    FP: 30
#    FN: 49
#    Precisión: 0.8148
#    Recall: 0.7293
#    F1-score: 0.7697
#
# Categoría: cotton
#    TP: 39
#    FP: 15
#    FN: 0
#    Precisión: 0.7222
#    Recall: 1.0000
#    F1-score: 0.8387
#
# Categoría: cotton-oil
#    TP: 0
#    FP: 0
#    FN: 1
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: cpi
#    TP: 2
#    FP: 3
#    FN: 67
#    Precisión: 0.4000
#    Recall: 0.0290
#    F1-score: 0.0541
#
# Categoría: cpu
#    TP: 0
#    FP: 0
#    FN: 3
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: crude
#    TP: 179
#    FP: 58
#    FN: 210
#    Precisión: 0.7553
#    Recall: 0.4602
#    F1-score: 0.5719
#
# Categoría: dfl
#    TP: 0
#    FP: 0
#    FN: 2
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: dlr
#    TP: 27
#    FP: 655
#    FN: 104
#    Precisión: 0.0396
#    Recall: 0.2061
#    F1-score: 0.0664
#
# Categoría: dmk
#    TP: 0
#    FP: 0
#    FN: 10
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: earn
#    TP: 17
#    FP: 19
#    FN: 2860
#    Precisión: 0.4722
#    Recall: 0.0059
#    F1-score: 0.0117
#
# Categoría: fuel
#    TP: 13
#    FP: 57
#    FN: 0
#    Precisión: 0.1857
#    Recall: 1.0000
#    F1-score: 0.3133
#
# Categoría: gas
#    TP: 7
#    FP: 260
#    FN: 30
#    Precisión: 0.0262
#    Recall: 0.1892
#    F1-score: 0.0461
#
# Categoría: gnp
#    TP: 36
#    FP: 10
#    FN: 65
#    Precisión: 0.7826
#    Recall: 0.3564
#    F1-score: 0.4898
#
# Categoría: gold
#    TP: 94
#    FP: 69
#    FN: 0
#    Precisión: 0.5767
#    Recall: 1.0000
#    F1-score: 0.7315
#
# Categoría: grain
#    TP: 182
#    FP: 28
#    FN: 251
#    Precisión: 0.8667
#    Recall: 0.4203
#    F1-score: 0.5661
#
# Categoría: groundnut
#    TP: 0
#    FP: 3
#    FN: 5
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: groundnut-oil
#    TP: 0
#    FP: 0
#    FN: 1
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: heat
#    TP: 0
#    FP: 11
#    FN: 14
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: hog
#    TP: 9
#    FP: 5
#    FN: 7
#    Precisión: 0.6429
#    Recall: 0.5625
#    F1-score: 0.6000
#
# Categoría: housing
#    TP: 12
#    FP: 24
#    FN: 4
#    Precisión: 0.3333
#    Recall: 0.7500
#    F1-score: 0.4615
#
# Categoría: income
#    TP: 4
#    FP: 296
#    FN: 5
#    Precisión: 0.0133
#    Recall: 0.4444
#    F1-score: 0.0259
#
# Categoría: instal-debt
#    TP: 0
#    FP: 0
#    FN: 5
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: interest
#    TP: 121
#    FP: 483
#    FN: 226
#    Precisión: 0.2003
#    Recall: 0.3487
#    F1-score: 0.2545
#
# Categoría: ipi
#    TP: 0
#    FP: 0
#    FN: 41
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: iron-steel
#    TP: 0
#    FP: 0
#    FN: 40
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: jet
#    TP: 3
#    FP: 3
#    FN: 1
#    Precisión: 0.5000
#    Recall: 0.7500
#    F1-score: 0.6000
#
# Categoría: jobs
#    TP: 8
#    FP: 38
#    FN: 38
#    Precisión: 0.1739
#    Recall: 0.1739
#    F1-score: 0.1739
#
# Categoría: l-cattle
#    TP: 0
#    FP: 0
#    FN: 6
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: lead
#    TP: 14
#    FP: 124
#    FN: 1
#    Precisión: 0.1014
#    Recall: 0.9333
#    F1-score: 0.1830
#
# Categoría: lei
#    TP: 0
#    FP: 0
#    FN: 12
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: lin-oil
#    TP: 1
#    FP: 0
#    FN: 0
#    Precisión: 1.0000
#    Recall: 1.0000
#    F1-score: 1.0000
#
# Categoría: livestock
#    TP: 15
#    FP: 17
#    FN: 60
#    Precisión: 0.4688
#    Recall: 0.2000
#    F1-score: 0.2804
#
# Categoría: lumber
#    TP: 6
#    FP: 12
#    FN: 4
#    Precisión: 0.3333
#    Recall: 0.6000
#    F1-score: 0.4286
#
# Categoría: meal-feed
#    TP: 0
#    FP: 0
#    FN: 30
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: money-fx
#    TP: 0
#    FP: 0
#    FN: 538
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: money-supply
#    TP: 0
#    FP: 0
#    FN: 140
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: naphtha
#    TP: 2
#    FP: 3
#    FN: 0
#    Precisión: 0.4000
#    Recall: 1.0000
#    F1-score: 0.5714
#
# Categoría: nat-gas
#    TP: 0
#    FP: 0
#    FN: 75
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: nickel
#    TP: 7
#    FP: 4
#    FN: 1
#    Precisión: 0.6364
#    Recall: 0.8750
#    F1-score: 0.7368
#
# Categoría: nkr
#    TP: 0
#    FP: 0
#    FN: 1
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: nzdlr
#    TP: 0
#    FP: 0
#    FN: 2
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: oat
#    TP: 1
#    FP: 1
#    FN: 7
#    Precisión: 0.5000
#    Recall: 0.1250
#    F1-score: 0.2000
#
# Categoría: oilseed
#    TP: 15
#    FP: 4
#    FN: 109
#    Precisión: 0.7895
#    Recall: 0.1210
#    F1-score: 0.2098
#
# Categoría: orange
#    TP: 12
#    FP: 5
#    FN: 4
#    Precisión: 0.7059
#    Recall: 0.7500
#    F1-score: 0.7273
#
# Categoría: palladium
#    TP: 2
#    FP: 2
#    FN: 0
#    Precisión: 0.5000
#    Recall: 1.0000
#    F1-score: 0.6667
#
# Categoría: palm-oil
#    TP: 0
#    FP: 0
#    FN: 30
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: palmkernel
#    TP: 0
#    FP: 1
#    FN: 2
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: pet-chem
#    TP: 0
#    FP: 0
#    FN: 20
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: platinum
#    TP: 5
#    FP: 5
#    FN: 0
#    Precisión: 0.5000
#    Recall: 1.0000
#    F1-score: 0.6667
#
# Categoría: potato
#    TP: 3
#    FP: 3
#    FN: 0
#    Precisión: 0.5000
#    Recall: 1.0000
#    F1-score: 0.6667
#
# Categoría: propane
#    TP: 2
#    FP: 3
#    FN: 1
#    Precisión: 0.4000
#    Recall: 0.6667
#    F1-score: 0.5000
#
# Categoría: rand
#    TP: 2
#    FP: 20
#    FN: 0
#    Precisión: 0.0909
#    Recall: 1.0000
#    F1-score: 0.1667
#
# Categoría: rape-oil
#    TP: 0
#    FP: 0
#    FN: 5
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: rapeseed
#    TP: 16
#    FP: 6
#    FN: 2
#    Precisión: 0.7273
#    Recall: 0.8889
#    F1-score: 0.8000
#
# Categoría: reserves
#    TP: 51
#    FP: 227
#    FN: 4
#    Precisión: 0.1835
#    Recall: 0.9273
#    F1-score: 0.3063
#
# Categoría: retail
#    TP: 17
#    FP: 75
#    FN: 6
#    Precisión: 0.1848
#    Recall: 0.7391
#    F1-score: 0.2957
#
# Categoría: rice
#    TP: 34
#    FP: 14
#    FN: 1
#    Precisión: 0.7083
#    Recall: 0.9714
#    F1-score: 0.8193
#
# Categoría: rubber
#    TP: 36
#    FP: 17
#    FN: 1
#    Precisión: 0.6792
#    Recall: 0.9730
#    F1-score: 0.8000
#
# Categoría: rye
#    TP: 1
#    FP: 1
#    FN: 0
#    Precisión: 0.5000
#    Recall: 1.0000
#    F1-score: 0.6667
#
# Categoría: ship
#    TP: 35
#    FP: 21
#    FN: 162
#    Precisión: 0.6250
#    Recall: 0.1777
#    F1-score: 0.2767
#
# Categoría: silver
#    TP: 20
#    FP: 27
#    FN: 1
#    Precisión: 0.4255
#    Recall: 0.9524
#    F1-score: 0.5882
#
# Categoría: sorghum
#    TP: 22
#    FP: 5
#    FN: 2
#    Precisión: 0.8148
#    Recall: 0.9167
#    F1-score: 0.8627
#
# Categoría: soy-meal
#    TP: 8
#    FP: 0
#    FN: 5
#    Precisión: 1.0000
#    Recall: 0.6154
#    F1-score: 0.7619
#
# Categoría: soy-oil
#    TP: 3
#    FP: 4
#    FN: 11
#    Precisión: 0.4286
#    Recall: 0.2143
#    F1-score: 0.2857
#
# Categoría: soybean
#    TP: 58
#    FP: 22
#    FN: 20
#    Precisión: 0.7250
#    Recall: 0.7436
#    F1-score: 0.7342
#
# Categoría: strategic-metal
#    TP: 0
#    FP: 0
#    FN: 16
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: sugar
#    TP: 119
#    FP: 27
#    FN: 7
#    Precisión: 0.8151
#    Recall: 0.9444
#    F1-score: 0.8750
#
# Categoría: sun-meal
#    TP: 0
#    FP: 2
#    FN: 1
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: sun-oil
#    TP: 1
#    FP: 0
#    FN: 4
#    Precisión: 1.0000
#    Recall: 0.2000
#    F1-score: 0.3333
#
# Categoría: sunseed
#    TP: 0
#    FP: 0
#    FN: 11
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: tea
#    TP: 9
#    FP: 12
#    FN: 0
#    Precisión: 0.4286
#    Recall: 1.0000
#    F1-score: 0.6000
#
# Categoría: tin
#    TP: 18
#    FP: 10
#    FN: 0
#    Precisión: 0.6429
#    Recall: 1.0000
#    F1-score: 0.7826
#
# Categoría: trade
#    TP: 343
#    FP: 467
#    FN: 25
#    Precisión: 0.4235
#    Recall: 0.9321
#    F1-score: 0.5823
#
# Categoría: veg-oil
#    TP: 0
#    FP: 0
#    FN: 87
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: wheat
#    TP: 203
#    FP: 38
#    FN: 9
#    Precisión: 0.8423
#    Recall: 0.9575
#    F1-score: 0.8962
#
# Categoría: wpi
#    TP: 0
#    FP: 0
#    FN: 19
#    Precisión: 0.0000
#    Recall: 0.0000
#    F1-score: 0.0000
#
# Categoría: yen
#    TP: 44
#    FP: 169
#    FN: 1
#    Precisión: 0.2066
#    Recall: 0.9778
#    F1-score: 0.3411
#
# Categoría: zinc
#    TP: 21
#    FP: 6
#    FN: 0
#    Precisión: 0.7778
#    Recall: 1.0000
#    F1-score: 0.8750
#
# Métricas globales:
#    Precisión Global: 0.3458
#    Recall Global: 0.4423
#    F1-score Global: 0.3352
